# %% [markdown]
# # Controle de carteiras Exponential Coins

# %% [markdown]
# ## Pacotes necessários

# %%
# !pip install requests
# !pip install pandas
# !pip install pycoingecko
# !pip install fredapi
# !pip install numpy
# !pip install plotly
# !pip install matplotlib
# !pip install yfinance
# !pip install nbformat
# Out:
# Requirement already satisfied: requests in c:\users\melogd1\downloads\colabmissioncontrol\venv\lib\site-packages (2.32.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\melogd1\downloads\colabmissioncontrol\venv\lib\site-packages (from requests) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\melogd1\downloads\colabmissioncontrol\venv\lib\site-packages (from requests) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\melogd1\downloads\colabmissioncontrol\venv\lib\site-packages (from requests) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\melogd1\downloads\colabmissioncontrol\venv\lib\site-packages (from requests) (2026.1.4)
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: pandas in c:\users\melogd1\downloads\colabmissioncontrol\venv\lib\site-packages (3.0.0)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\melogd1\downloads\colabmissioncontrol\venv\lib\site-packages (from pandas) (2.4.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\melogd1\downloads\colabmissioncontrol\venv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\users\melogd1\downloads\colabmissioncontrol\venv\lib\site-packages (from pandas) (2025.3)
# Requirement already satisfied: six>=1.5 in c:\users\melogd1\downloads\colabmissioncontrol\venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: pycoingecko in c:\users\melogd1\downloads\colabmissioncontrol\venv\lib\site-packages (3.2.0)
# Requirement already satisfied: requests in c:\users\melogd1\downloads\colabmissioncontrol\venv\lib\site-packages (from pycoingecko) (2.32.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\melogd1\downloads\colabmissioncontrol\venv\lib\site-packages (from requests->pycoingecko) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\melogd1\downloads\colabmissioncontrol\venv\lib\site-packages (from requests->pycoingecko) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\melogd1\downloads\colabmissioncontrol\venv\lib\site-packages (from requests->pycoingecko) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\melogd1\downloads\colabmissioncontrol\venv\lib\site-packages (from requests->pycoingecko) (2026.1.4)
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: fredapi in c:\users\melogd1\downloads\colabmissioncontrol\venv\lib\site-packages (0.5.2)
# Requirement already satisfied: pandas in c:\users\melogd1\downloads\colabmissioncontrol\venv\lib\site-packages (from fredapi) (3.0.0)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\melogd1\downloads\colabmissioncontrol\venv\lib\site-packages (from pandas->fredapi) (2.4.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\melogd1\downloads\colabmissioncontrol\venv\lib\site-packages (from pandas->fredapi) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\users\melogd1\downloads\colabmissioncontrol\venv\lib\site-packages (from pandas->fredapi) (2025.3)
# Requirement already satisfied: six>=1.5 in c:\users\melogd1\downloads\colabmissioncontrol\venv\lib\site-packages (from python-dateutil>=2.8.2->pandas->fredapi) (1.17.0)
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: numpy in c:\users\melogd1\downloads\colabmissioncontrol\venv\lib\site-packages (2.4.2)
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: plotly in c:\users\melogd1\downloads\colabmissioncontrol\venv\lib\site-packages (6.5.2)
# Requirement already satisfied: narwhals>=1.15.1 in c:\users\melogd1\downloads\colabmissioncontrol\venv\lib\site-packages (from plotly) (2.16.0)
# Requirement already satisfied: packaging in c:\users\melogd1\downloads\colabmissioncontrol\venv\lib\site-packages (from plotly) (26.0)
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: matplotlib in c:\users\melogd1\downloads\colabmissioncontrol\venv\lib\site-packages (3.10.8)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\melogd1\downloads\colabmissioncontrol\venv\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\melogd1\downloads\colabmissioncontrol\venv\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\melogd1\downloads\colabmissioncontrol\venv\lib\site-packages (from matplotlib) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\melogd1\downloads\colabmissioncontrol\venv\lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in c:\users\melogd1\downloads\colabmissioncontrol\venv\lib\site-packages (from matplotlib) (2.4.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\melogd1\downloads\colabmissioncontrol\venv\lib\site-packages (from matplotlib) (26.0)
# Requirement already satisfied: pillow>=8 in c:\users\melogd1\downloads\colabmissioncontrol\venv\lib\site-packages (from matplotlib) (12.1.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\melogd1\downloads\colabmissioncontrol\venv\lib\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\melogd1\downloads\colabmissioncontrol\venv\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\melogd1\downloads\colabmissioncontrol\venv\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: yfinance in c:\users\melogd1\downloads\colabmissioncontrol\venv\lib\site-packages (1.1.0)
# Requirement already satisfied: pandas>=1.3.0 in c:\users\melogd1\downloads\colabmissioncontrol\venv\lib\site-packages (from yfinance) (3.0.0)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\melogd1\downloads\colabmissioncontrol\venv\lib\site-packages (from yfinance) (2.4.2)
# Requirement already satisfied: requests>=2.31 in c:\users\melogd1\downloads\colabmissioncontrol\venv\lib\site-packages (from yfinance) (2.32.5)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\melogd1\downloads\colabmissioncontrol\venv\lib\site-packages (from yfinance) (0.0.12)
# Requirement already satisfied: platformdirs>=2.0.0 in c:\users\melogd1\downloads\colabmissioncontrol\venv\lib\site-packages (from yfinance) (4.5.1)
# Requirement already satisfied: pytz>=2022.5 in c:\users\melogd1\downloads\colabmissioncontrol\venv\lib\site-packages (from yfinance) (2025.2)
# Requirement already satisfied: frozendict>=2.3.4 in c:\users\melogd1\downloads\colabmissioncontrol\venv\lib\site-packages (from yfinance) (2.4.7)
# Requirement already satisfied: peewee>=3.16.2 in c:\users\melogd1\downloads\colabmissioncontrol\venv\lib\site-packages (from yfinance) (3.19.0)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\melogd1\downloads\colabmissioncontrol\venv\lib\site-packages (from yfinance) (4.14.3)
# Requirement already satisfied: curl_cffi<0.14,>=0.7 in c:\users\melogd1\downloads\colabmissioncontrol\venv\lib\site-packages (from yfinance) (0.13.0)
# Requirement already satisfied: protobuf>=3.19.0 in c:\users\melogd1\downloads\colabmissioncontrol\venv\lib\site-packages (from yfinance) (6.33.5)
# Requirement already satisfied: websockets>=13.0 in c:\users\melogd1\downloads\colabmissioncontrol\venv\lib\site-packages (from yfinance) (16.0)
# Requirement already satisfied: soupsieve>=1.6.1 in c:\users\melogd1\downloads\colabmissioncontrol\venv\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.8.3)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\melogd1\downloads\colabmissioncontrol\venv\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (4.15.0)
# Requirement already satisfied: cffi>=1.12.0 in c:\users\melogd1\downloads\colabmissioncontrol\venv\lib\site-packages (from curl_cffi<0.14,>=0.7->yfinance) (2.0.0)
# Requirement already satisfied: certifi>=2024.2.2 in c:\users\melogd1\downloads\colabmissioncontrol\venv\lib\site-packages (from curl_cffi<0.14,>=0.7->yfinance) (2026.1.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\melogd1\downloads\colabmissioncontrol\venv\lib\site-packages (from pandas>=1.3.0->yfinance) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\users\melogd1\downloads\colabmissioncontrol\venv\lib\site-packages (from pandas>=1.3.0->yfinance) (2025.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\melogd1\downloads\colabmissioncontrol\venv\lib\site-packages (from requests>=2.31->yfinance) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\melogd1\downloads\colabmissioncontrol\venv\lib\site-packages (from requests>=2.31->yfinance) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\melogd1\downloads\colabmissioncontrol\venv\lib\site-packages (from requests>=2.31->yfinance) (2.6.3)
# Requirement already satisfied: pycparser in c:\users\melogd1\downloads\colabmissioncontrol\venv\lib\site-packages (from cffi>=1.12.0->curl_cffi<0.14,>=0.7->yfinance) (3.0)
# Requirement already satisfied: six>=1.5 in c:\users\melogd1\downloads\colabmissioncontrol\venv\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.3.0->yfinance) (1.17.0)
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: nbformat in c:\users\melogd1\downloads\colabmissioncontrol\venv\lib\site-packages (5.10.4)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\users\melogd1\downloads\colabmissioncontrol\venv\lib\site-packages (from nbformat) (2.21.2)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\melogd1\downloads\colabmissioncontrol\venv\lib\site-packages (from nbformat) (4.26.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\melogd1\downloads\colabmissioncontrol\venv\lib\site-packages (from nbformat) (5.9.1)
# Requirement already satisfied: traitlets>=5.1 in c:\users\melogd1\downloads\colabmissioncontrol\venv\lib\site-packages (from nbformat) (5.14.3)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\melogd1\downloads\colabmissioncontrol\venv\lib\site-packages (from jsonschema>=2.6->nbformat) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\melogd1\downloads\colabmissioncontrol\venv\lib\site-packages (from jsonschema>=2.6->nbformat) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\melogd1\downloads\colabmissioncontrol\venv\lib\site-packages (from jsonschema>=2.6->nbformat) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in c:\users\melogd1\downloads\colabmissioncontrol\venv\lib\site-packages (from jsonschema>=2.6->nbformat) (0.30.0)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\melogd1\downloads\colabmissioncontrol\venv\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat) (4.5.1)
# Requirement already satisfied: typing-extensions>=4.4.0 in c:\users\melogd1\downloads\colabmissioncontrol\venv\lib\site-packages (from referencing>=0.28.4->jsonschema>=2.6->nbformat) (4.15.0)
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ## Autorização Google Sheets

# %%
# ==========================================
# Configuracao de Diretorios Locais
# ==========================================
# Este notebook foi configurado para rodar localmente
# sem dependencia do Google Sheets ou Google Drive.
# Os dados sao lidos de arquivos CSV locais.

import os
from pathlib import Path

# Diretorio base do projeto (onde esta o notebook)
BASE_DIR = Path(os.getcwd())

# Diretorios de dados
DATA_DIR = BASE_DIR / "data"
ALLOCATIONS_DIR = DATA_DIR / "allocations"
CATEGORIES_DIR = DATA_DIR / "categories"
PRICES_DIR = DATA_DIR / "prices"
OUTPUT_DIR = BASE_DIR / "output"

# Criar diretorios se nao existirem
for dir_path in [ALLOCATIONS_DIR, CATEGORIES_DIR, PRICES_DIR, OUTPUT_DIR]:
    dir_path.mkdir(parents=True, exist_ok=True)

print(f"Diretorio base: {BASE_DIR}")
print(f"Diretorio de precos: {PRICES_DIR}")
print(f"Diretorio de alocacoes: {ALLOCATIONS_DIR}")
print(f"Diretorio de categorias: {CATEGORIES_DIR}")
print(f"Diretorio de output: {OUTPUT_DIR}")
print("Configuracao local concluida!")
# Out:
# Diretorio base: c:\Users\melogd1\Downloads\colabMissionControl
# Diretorio de precos: c:\Users\melogd1\Downloads\colabMissionControl\data\prices
# Diretorio de alocacoes: c:\Users\melogd1\Downloads\colabMissionControl\data\allocations
# Diretorio de categorias: c:\Users\melogd1\Downloads\colabMissionControl\data\categories
# Diretorio de output: c:\Users\melogd1\Downloads\colabMissionControl\output
# Configuracao local concluida!

# %% [markdown]
# ## Classe Carteira
#
# Este objeto python é uma classe que realiza uma série de funções para facilitar o controle de carteira de cripto ativos, requerendo apenas agluns argumentos:
#
# 1. Nome da Carteira
# 2. Lista de ativos (ids de API do CoinGecko)
# 3. Alocação (manuseadas via sheets e importadas nesse notebook)
# 4. Categorias (manuseadas via sheets e importadas nesse notebook)
#
# O objeto cria um diretório de ativos em pastas individuais, e atualiza-as individualmente toda vez que o script é rodado.
#
# O diretório de ativos é mapeado para um dataframe consolidado, com base na planilha de alocações. Portanto, todo o controle desse objeto está baseado na:
#
#
# 1. Atualização de planilhas (criação de colunas e atualização de alocações)
# 2. Atualização da lista de ids de API para cada carteira (cada uma tem sua lista).

# %%
import os
import time
import numpy as np
import pandas as pd
from datetime import datetime, timedelta
from pycoingecko import CoinGeckoAPI
import warnings
import requests
import plotly.graph_objects as go

warnings.filterwarnings("ignore")


class PortfolioCrypto:

    cg = CoinGeckoAPI(api_key="CG-S24fNKNPYgDiQfRfPpxCPnTP")
    _coins = None

    @classmethod
    def get_coins_list(cls):
        if cls._coins is None:
            cls._coins = cls.cg.get_coins_list()
        return cls._coins


    def __init__(self, carteira, ativos, aloc, categorias):
        self.nome = carteira
        self.ativos = ativos
        self.aloc = aloc
        self.categorias = categorias
        self.df_aloc = pd.DataFrame(self.aloc)
        self.df_cats = pd.DataFrame(self.categorias)
        self.df_aloc_balanceada_alerta = pd.DataFrame()
        self.df_aloc_balanceada_periodo = pd.DataFrame()
        self.df_precos = pd.DataFrame()
        self.df_ptax = pd.DataFrame()
        self.df_btc = pd.DataFrame()
        self.df_retornos = pd.DataFrame()
        self.df_retornos_ponderados = pd.DataFrame()
        self._atualizar_cotacoes()
        self.ptax()
        self._get_filtered_coins()
        self.precos()
        self.calcular_retornos()
        self.calcular_retornos_ponderados()
        self.calcular_posicao_balanceada_alerta()
        self.mapeamento_ticker_id = {}

    def _get_filtered_coins(self):
      coins_df = pd.DataFrame(self.get_coins_list())
      filtered_coins_df = coins_df[coins_df['id'].isin(self.ativos)]
      self.mapeamento_ticker_id = {row['symbol'].upper(): row['id'] for index, row in filtered_coins_df.iterrows()}


    def _atualizar_cotacoes(self):
      total_ativos = len(self.ativos)

      # Contador de ativos efetivamente processados
      ativos_processados = 0

      for i, ativo in enumerate(self.ativos, start=1):

          print(f"Processando {i} de {total_ativos}: {ativo}")

          arquivo = PRICES_DIR / f"{ativo}.csv"

          if os.path.exists(arquivo):
              df_existente = pd.read_csv(arquivo, parse_dates=['data'], index_col='data')
              ultima_data = df_existente.index[-1].date()
              #print(f"Ultima data: {ultima_data}")

              if ultima_data == (datetime.now() - timedelta(days=1)).date():
                 print(f"{ativo} OK!")
                 continue

              dias_para_atualizar = (datetime.now().date() - ultima_data).days - 1
          else:
              dias_para_atualizar = "max"  # Fetch all available history

          try:
              dados = self.cg.get_coin_market_chart_by_id(id=ativo, vs_currency='usd', days=str(dias_para_atualizar), interval='daily')

              # Incremente o contador de ativos efetivamente processados
              ativos_processados += 1

          except Exception as e:
              print(f"Erro ao buscar dados para {ativo}: {e}")
              continue

          df_novo = pd.DataFrame(dados['prices'], columns=['data', 'close'])
          df_novo['data'] = pd.to_datetime(df_novo['data'], unit='ms').dt.normalize()

          # Remove a última linha (preço atual)
          df_novo = df_novo.iloc[:-1]

          # Ajusta a data para o fechamento do dia anterior
          df_novo['data'] = df_novo['data'] - timedelta(days=1)

          df_novo.set_index('data', inplace=True)

          # Certifique-se de que o índice seja único
          df_novo = df_novo[~df_novo.index.duplicated(keep='first')]

          # Interpolar dados se houver gaps
          df_novo = df_novo.asfreq('D', method='pad')

          if os.path.exists(arquivo):
              df_atualizado = pd.concat([df_existente, df_novo]).drop_duplicates()
          else:
              df_atualizado = df_novo

          df_atualizado.to_csv(arquivo)

          # Verificar pausa da API usando o contador de ativos efetivamente processados
          #if ativos_processados % 18 == 0:
           #   print(f"API cooldown (1m)...")
            #  time.sleep(61)



    def precos(self):

        self._get_filtered_coins()
        self.df_aloc.columns = map(str.upper, self.df_aloc.columns)
        df_precos = pd.DataFrame(index=self.df_aloc.index)

        for coluna in self.df_aloc.columns:
            if coluna in self.mapeamento_ticker_id:
                id_ativo = self.mapeamento_ticker_id[coluna]

                try:
                    df_ativo = pd.read_csv(PRICES_DIR / f"{id_ativo}.csv", index_col='data', parse_dates=True)
                    df_ativo = df_ativo.groupby(df_ativo.index).first()

                    # Caso 1: Ativo já existia antes da carteira ser criada

                    if df_ativo.index[0] <= self.df_aloc.index[0]:
                        df_precos[coluna] = df_ativo['close'].reindex(self.df_aloc.index, method='ffill')

                    # Caso 2: Ativo foi criado depois do lançamento da carteira
                    else:
                        first_price = df_ativo['close'].iloc[0]  # Primeiro preço disponível
                        df_precos[coluna] = np.nan  # Inicialmente, preenche com NaN
                        df_precos.loc[df_ativo.index[0]:, coluna] = df_ativo['close']  # Preenche com preços reais quando disponíveis
                        df_precos.loc[:df_ativo.index[0], coluna] = first_price  # Preenche com o primeiro preço até a data de início

                except FileNotFoundError:
                    print(f"Arquivo para {id_ativo} não encontrado.")



        self.df_precos = df_precos



        return self.df_precos


    def calcular_retornos(self):

        df_retornos = self.df_precos.pct_change()
        df_retornos.iloc[0, :] = 0

        stablecoins = ['TUSD', 'BUSD', 'USDT']
        for coin in stablecoins:
            if coin in df_retornos.columns:
                df_retornos[coin] = 0


        self.df_retornos = df_retornos
        return self.df_retornos


    def calcular_posicao_balanceada_alerta(self):


        cot_init = 10000
        df_aloc = self.df_aloc
        df_retornos = self.df_retornos

        # Ensure df_aloc is numeric
        df_aloc = df_aloc.map(
            lambda x: float(x.strip('%')) / 100 if isinstance(x, str) and '%' in x else x
        ).astype(float)

        # Align df_aloc and df_retornos
        common_columns = df_aloc.columns.intersection(df_retornos.columns)
        common_index = df_aloc.index.intersection(df_retornos.index)
        df_aloc = df_aloc.loc[common_index, common_columns]
        df_retornos = df_retornos.loc[common_index, common_columns]

        # Initialize df_posicao
        df_posicao = pd.DataFrame(index=df_aloc.index, columns=df_aloc.columns)
        df_posicao.iloc[0] = df_aloc.iloc[0] * cot_init

        # Debugging: Check initial positions
        print("Initial df_posicao:\n", df_posicao.iloc[0])

        # Update positions
        for i in range(1, len(df_posicao)):
            # Update based on returns
            df_posicao.iloc[i] = df_posicao.iloc[i-1] * (1 + df_retornos.iloc[i])

            # Rebalance if allocation changes
            if not df_aloc.iloc[i].equals(df_aloc.iloc[i-1]):
                valor_portfolio = df_posicao.iloc[i-1].sum()
                df_posicao.iloc[i] = df_aloc.iloc[i] * valor_portfolio
                df_posicao.iloc[i] = df_posicao.iloc[i] * (1 + df_retornos.iloc[i])

        # Debugging: Check for zero sums
        row_sums = df_posicao.sum(axis=1)
        zero_sum_rows = row_sums[row_sums == 0]
        if not zero_sum_rows.empty:
            print(f"Warning: Zero sum rows found in df_posicao at dates: {zero_sum_rows.index.tolist()}")
            print("df_posicao at zero sum rows:\n", df_posicao.loc[zero_sum_rows.index])
            print("df_aloc at zero sum rows:\n", df_aloc.loc[zero_sum_rows.index])
            print("df_retornos at zero sum rows:\n", df_retornos.loc[zero_sum_rows.index])

        # Handle zero sums by filling with previous non-zero sum or small positive value
        row_sums = row_sums.replace(0, np.nan).ffill().fillna(1e-10)

        # Compute relative allocations
        self.df_aloc_balanceada_alerta = df_posicao.div(row_sums, axis=0)

        # Add portfolio total
        df_posicao[self.nome] = df_posicao.sum(axis=1)
        self.df_posicao_balanceada_alerta = df_posicao

        return self.df_posicao_balanceada_alerta

    def calcular_retornos_ponderados(self):

        df_retornos = self.df_retornos
        df_aloc = self.df_aloc

        # planilhas do google as alocs vem como strings, por isso se converte (abaixo)
        df_aloc = df_aloc.map(lambda x: float(x.strip('%')) / 100 if isinstance(x, str) and '%' in x else x)

        df_retornos_ponderados = df_retornos.mul(df_aloc)

        df_retornos_ponderados[self.nome] = df_retornos_ponderados.sum(axis=1)

        self.df_retornos_ponderados = df_retornos_ponderados

        return self.df_retornos_ponderados


    def calcular_retornos_acumulados(self, inicio, fim, ponderar=False):
        """

        Args:
          inicio:
          fim:
          ponderar:

        Returns:

        """

        # Retornos Acumulados Não Ponderados
        self.df_retornos.loc[inicio:fim].iloc[0, :] = 0  # Preencher a primeira linha com 0%


        if 'BTC' in self.df_retornos.loc[inicio:fim].columns:
          self.df_btc = self.df_retornos.loc[inicio:fim][['BTC']]


        self.df_retornos_acumulados = (1 + self.df_retornos.loc[inicio:fim]).cumprod() - 1


        # Retornos Ponderados Acumulados
        df_retornos_ponderados = self.df_retornos_ponderados.loc[inicio:fim]
        df_retornos_ponderados.iloc[0, :] = 0  # Preencher a primeira linha com 0%
        self.df_retornos_acumulados_ponderados = (1+df_retornos_ponderados).cumprod() - 1


        # Manter apenas ativos que tiveram alocação > 0 em algum momento do período
        df_aloc_periodo = self.df_aloc.loc[inicio:fim].map(lambda x: float(str(x).strip('%'))/100 if isinstance(x, str) and '%' in str(x) else x).fillna(0)
        colunas_com_alocacao = df_aloc_periodo.columns[(df_aloc_periodo != 0).any(axis=0)]
        cols_retornos = [c for c in colunas_com_alocacao if c in self.df_retornos_acumulados.columns]
        cols_ponderados = [c for c in colunas_com_alocacao if c in self.df_retornos_acumulados_ponderados.columns]
        if self.nome in self.df_retornos_acumulados_ponderados.columns and self.nome not in cols_ponderados:
            cols_ponderados.append(self.nome)
        self.df_retornos_acumulados = self.df_retornos_acumulados[cols_retornos]
        self.df_retornos_acumulados_ponderados = self.df_retornos_acumulados_ponderados[cols_ponderados]

        # Remover colunas onde todos os elementos são iguais a zero
        self.df_retornos_acumulados = self.df_retornos_acumulados.loc[:, ~(self.df_retornos_acumulados == 0).all(axis=0)]
        self.df_retornos_acumulados_ponderados = self.df_retornos_acumulados_ponderados.loc[:, ~(self.df_retornos_acumulados_ponderados == 0).all(axis=0)]

        # Retorno Acumulado da Carteira

        self.df_retornos_acumulados[self.nome] = self.df_retornos_acumulados_ponderados[[self.nome]]

        if ponderar:
            return self.df_retornos_acumulados_ponderados
        else:
            return self.df_retornos_acumulados

    def ptax(self):
        start_date = "01/01/2017"
        end_date = datetime.today().strftime('%d/%m/%Y')

        base_url = "https://api.bcb.gov.br/dados/serie/bcdata.sgs.10813/dados"
        url = f"{base_url}?formato=json&dataInicial={start_date}&dataFinal={end_date}"

        response = requests.get(url)
        response.raise_for_status()

        data = response.json()
        df = pd.DataFrame(data)
        df['valor'] = df['valor'].str.replace(',', '.').astype(float)
        df['data'] = pd.to_datetime(df['data'], format='%d/%m/%Y')
        df.set_index('data', inplace=True)
        df = df.resample('D').ffill()
        df['ptax'] = df['valor'].pct_change().fillna(0)
        df = df[['ptax']]

        self.df_ptax = df

        return self.df_ptax


    def calcular_var_historico(self, ativo, nivel_confianca=95, janela_amostral=365, periodo=7):
        """
        Calcula o Value at Risk (VaR) histórico para um ativo específico.

        :param ativo: String, o nome do ativo na carteira.
        :param nivel_confianca: Float, o nível de confiança para o cálculo do VaR (padrão 95%).
        :param janela_dias: Int, o número de dias para a amostragem histórica (padrão 365 dias).
        :return: Float, o VaR do ativo.
        """

        if ativo not in self.df_retornos.columns:
            raise ValueError(f"O ativo {ativo} não está presente na carteira.")

        # Selecionar os retornos do ativo para o período especificado
        retornos_recentes = self.df_retornos[ativo].tail(janela_amostral)
        retornos_acumulados_periodo = (1 + retornos_recentes).rolling(window=periodo).apply(np.prod, raw=True) - 1


        # Calcular o VaR como o percentil da distribuição de retornos
        var = np.percentile(retornos_acumulados_periodo.dropna(), 100 - nivel_confianca).round(4) * 100

        return var

    def calcular_voo_historico(self, ativo, nivel_confianca=95, janela_amostral=365, periodo=7):
        """
        Calcula o Value at Opportunity (VoO) histórico para um ativo específico.

        :param ativo: String, o nome do ativo na carteira.
        :param nivel_confianca: Float, o nível de confiança para o cálculo do VoO (padrão 95%).
        :param janela_dias: Int, o número de dias para a amostragem histórica (padrão 365 dias).
        :param periodo: Int, o número de dias para acumular os retornos (padrão 1, para retornos diários).
        :return: Float, o VoO do ativo.
        """
        if ativo not in self.df_retornos.columns:
            raise ValueError(f"O ativo {ativo} não está presente na carteira.")

        # Selecionar os retornos do ativo para o período especificado
        retornos_recentes = self.df_retornos[ativo].tail(janela_amostral)

        # Se o período é maior que 1 dia, calcular os retornos acumulados
        if periodo > 1:
            retornos_recentes = (1 + retornos_recentes).rolling(window=periodo).apply(np.prod, raw=True) - 1

        # Calcular o VoO como o percentil superior da distribuição de retornos
        voo = np.percentile(retornos_recentes.dropna(), nivel_confianca).round(4) * 100

        return voo

    def beta(self, inicio, fim):

        # Consertar

        df_carteira = self.df_retornos_ponderados[[self.nome]]
        df_ret = self.df_retornos[inicio:fim]
        df_ret = df_ret.merge(df_carteira[[self.nome]], on='Data')


        df_btc = pd.read_csv(PRICES_DIR / "bitcoin.csv", index_col='data').pct_change().fillna(0)
        df_btc = df_btc[inicio:fim]
        df_btc.index.rename('Data', inplace=True)
        df_btc.rename(columns={'close': 'BTC'}, inplace=True)
        df_btc.index = pd.to_datetime(df_btc.index)


        if 'BTC' not in df_ret.columns:
          df_ret = df_ret.merge(df_btc[['BTC']], on='Data')



        btc_var = df_ret['BTC'].var()

        betas = {}

        for ativo in df_ret.columns:
          if ativo != 'BTC':
            covariance = df_ret[ativo].cov(df_ret['BTC'])

            beta = round(covariance / btc_var, 4)

            betas[ativo] = beta

        return betas

    def rolling_beta(self, inicio, fim, janela=30):

        inicio = pd.to_datetime(inicio)
        fim = pd.to_datetime(fim)

        rolling_betas = pd.DataFrame()


        for start in pd.date_range(inicio, fim - pd.Timedelta(days=janela)):

            end = start + pd.Timedelta(days=janela)


            betas = self.beta(start.strftime('%Y-%m-%d'), end.strftime('%Y-%m-%d'))


            betas_df = pd.DataFrame(betas, index=[end])

            rolling_betas = pd.concat([rolling_betas, betas_df])

        return rolling_betas

    def posicoes_fechadas(self):

        df_aloc = self.df_aloc.map(lambda x: float(x.strip('%')) / 100 if isinstance(x, str) and '%' in x else x)
        df_preco = self.df_precos
        resultados = []

        stablecoins = ['USDT', 'BUSD', 'TUSD']

        for ativo in df_aloc.columns:
          if ativo not in stablecoins:
            alocacao_ativo = df_aloc[ativo]
            preco_ativo = df_preco[ativo]

            dentro_da_carteira = False

            for i in range(len(alocacao_ativo)):
                if alocacao_ativo.iloc[i] != 0 and not dentro_da_carteira:
                    # Início do período
                    data_entrada = alocacao_ativo.index[i]
                    preco_entrada = round(preco_ativo[data_entrada],5)
                    dentro_da_carteira = True

                elif alocacao_ativo.iloc[i] == 0 and dentro_da_carteira:
                    # Fim do período
                    data_saida = alocacao_ativo.index[i]
                    dias_em_carteira = (pd.to_datetime(data_saida) - pd.to_datetime(data_entrada)).days
                    preco_saida = round(preco_ativo[data_saida],5)
                    retorno = round(((preco_saida - preco_entrada) / preco_entrada) * 100, 2)
                    resultados.append([ativo, data_entrada, data_saida, dias_em_carteira, preco_entrada, preco_saida, retorno])
                    dentro_da_carteira = False

        results = pd.DataFrame(resultados, columns=['ativo', 'data_entrada', 'data_saida', 'dias_em_carteira', 'preco_entrada', 'preco_saida', 'retorno_acumulado(%)']).sort_values(by=['retorno_acumulado(%)'], ascending=False, ignore_index=True)
        results.to_csv(OUTPUT_DIR / f'historico_de_recomendacoes_{self.nome}.csv')
        return results

    import pandas as pd

    def posicoes_abertas(self):
        df_aloc = self.df_aloc.map(lambda x: float(x.strip('%')) / 100 if isinstance(x, str) and '%' in x else x)
        df_preco = self.df_precos
        resultados = []

        stablecoins = ['USDT', 'BUSD', 'TUSD']
        ultima_linha = df_aloc.iloc[-1]  # Última linha da planilha de alocações

        for ativo in ultima_linha.index:
            if ativo not in stablecoins and ultima_linha[ativo] != 0:
                alocacao_ativo = df_aloc[ativo]
                preco_ativo = df_preco[ativo]

                # Encontrar a última data de entrada
                datas_entrada = alocacao_ativo[alocacao_ativo.ne(0) & alocacao_ativo.shift(1).eq(0)].index
                if len(datas_entrada) > 0:
                    ultima_entrada = datas_entrada[-1]
                    dias_em_carteira = (pd.to_datetime(datetime.today()) - pd.to_datetime(ultima_entrada)).days
                elif alocacao_ativo.ne(0).all():
                    # Se o ativo sempre esteve na carteira, usar a primeira data do DataFrame
                    ultima_entrada = alocacao_ativo.index[0]
                    dias_em_carteira = (pd.to_datetime(datetime.today()) - pd.to_datetime(ultima_entrada)).days

                preco_entrada = round(preco_ativo[ultima_entrada], 3)
                preco_atual = round(preco_ativo.iloc[-1], 3)
                valorizacao = round(((preco_atual - preco_entrada) / preco_entrada) * 100, 3) if preco_entrada != 0 else 0

                resultados.append([ativo, ultima_entrada, dias_em_carteira, preco_entrada, preco_atual, valorizacao])



        results = pd.DataFrame(resultados, columns=['ativo', 'ultima_entrada', 'dias_em_carteira', 'preco_entrada', 'preco_atual', 'retorno_acumulado(%)']).sort_values(by=['retorno_acumulado(%)'], ascending=False ,ignore_index=True)
        results.to_csv(OUTPUT_DIR / f'posicoes_abertas_{self.nome}.csv')
        return results

# %% [markdown]
# ## Funções auxiliares
#
# As funções abaixo recebem uma instância de carteira, e possivelmente mais alguns outros argumentos, como datas de `início` e `fim`.

# %% [markdown]
# ### Plotar resultado das carteiras
#
# Argumentos da função:
# 1. `inicio`: 'YYYY-MM-DD'
# 2. `fim`: 'YYYY-MM-DD'
# 3. `carteira`: *exc*, *hb* ou *lc*
# 4. `brl`: True ou False (retorna a valorização em BRL)

# %%
def plot_carteiras(inicio, fim, *carteiras, brl=False):

    # Calcula os retornos acumulados ponderados para cada carteira dentro das datas especificadas
    data_frames = [carteira.calcular_retornos_acumulados(inicio, fim, ponderar=True)[carteira.nome] for carteira in carteiras]

    # Adiciona o retorno acumulado do BTC
    btc = carteiras[0].df_btc.loc[inicio:fim]
    btc.iloc[0, :] = 0
    btc_acumulado = (1 + btc).cumprod() - 1
    btc_acumulado = btc_acumulado.rename(columns={"btc": "BTC"})
    data_frames.append(btc_acumulado)
    df = pd.concat(data_frames, axis=1)

    if brl:
      ptax = carteiras[0].df_ptax.loc[inicio:fim]
      ptax.iloc[0, :] = 0
      ptax['ptax_acumulado'] = (1+ptax).cumprod() - 1
      ptax = ptax[['ptax_acumulado']]
      df = (1+df).multiply(1+ptax['ptax_acumulado'], axis = 0) - 1



    df = df * 100



    # Plota o gráfico usando Plotly
    fig = go.Figure()

    for col in df.columns:
        fig.add_trace(go.Scatter(x=df.index, y=df[col], mode='lines', name=col,
                                 hovertemplate='%{y:.2f}%',
                                 line_shape='spline',  # Makes the lines smoother
                                 line=dict(width=2)))  # Adjust line width


    titulo = 'Rentabilidade das Carteiras (BRL)' if brl else 'Rentabilidade Carteiras (USD)'

    # Update layout to make it cleaner
    fig.update_layout(

        margin=dict(t=60),

        title={'text': titulo,
               'x': 0.055,  # Centering the title
               'y': 0.97,  # Position adjustment to leave space for subtitle
               'font': {'size': 18,  # Larger font size for title
                        'color': 'black',
                        'family': 'Georgia'}},  # Elegant serif font for title
        xaxis_title='',
        yaxis_title='Rentabilidade Acumulada (%)',
        legend_title="Carteiras e benchmarks: ",
        hovermode='x unified',
        plot_bgcolor='white',  # White background
        xaxis=dict(
            showline=True,
            showgrid=True,
            gridcolor='lightgray',  # Light gray grid lines
            linecolor='white',  # Remove border
            linewidth=2,
            zerolinecolor='lightgray'
        ),
        yaxis=dict(
            showline=True,
            showgrid=True,
            gridcolor='lightgray',
            linecolor='white',
            linewidth=2,
            zerolinecolor='lightgray'
        ),
        legend=dict(
            orientation='h',
            yanchor='bottom',
            y=1.02,
            xanchor='right',
            x=1
        ),
        font=dict(
            family='Georgia',  # Update font family (optional)
            size=15,  # Adjust font size
            color='black'  # Font color
        ),
        annotations=[  # Adding the subtitle
            dict(
                text=f'Período: {inicio} à {fim}',  # Subtitle text
                xref='paper', yref='paper',  # Reference to paper (entire figure)
                x=0.00001, y=1.065,  # Position of subtitle (underneath title)
                showarrow=False,  # We don't need an arrow pointing to our subtitle
                font=dict(
                    family='Georgia',
                    size=13,
                    color='gray'  # Gray color for subtitle
                )
            )
        ]
    )
    fig.show()

# %% [markdown]
# ### Plotar rebalanceamento diário vs. no alerta
#
# Argumentos da função:
# 1. `inicio`: 'YYYY-MM-DD'
# 2. `fim`: 'YYYY-MM-DD'
# 3. `carteiras`: ***exc*** (obrigatório), ***hb*** e/ou *lc* (opcionais)

# %%
def plot_comp_rebalanceamento(inicio, fim, carteira):


    df_ajustado = carteira.df_posicao_balanceada_alerta[carteira.nome]
    df_ajustado = df_ajustado[inicio:fim].pct_change().fillna(0)
    df_ajustado = (1+df_ajustado).cumprod()-1
    df_ajustado = df_ajustado.to_frame(name=carteira.nome + ' (Adj.)')

    df = carteira.calcular_retornos_acumulados(inicio,fim,ponderar=True)
    df = df[[carteira.nome]]

    data_frames = [df, df_ajustado]
    df = pd.concat(data_frames, axis=1)

    df = df * 100


    # Plota o gráfico usando Plotly
    fig = go.Figure()

    for col in df.columns:
        fig.add_trace(go.Scatter(x=df.index, y=df[col], mode='lines', name=col,
                                 hovertemplate='%{y:.2f}%',
                                 line_shape='spline',  # Makes the lines smoother
                                 line=dict(width=2)))  # Adjust line width


    titulo = 'Rebalanceamento diário vs. Rebalanceamento nos alertas'

    # Update layout to make it cleaner
    fig.update_layout(

        margin=dict(t=60),

        title={'text': titulo,
               'x': 0.055,  # Centering the title
               'y': 0.97,  # Position adjustment to leave space for subtitle
               'font': {'size': 18,  # Larger font size for title
                        'color': 'black',
                        'family': 'Georgia'}},  # Elegant serif font for title
        xaxis_title='',
        yaxis_title='Rentabilidade Acumulada (%)',
        legend_title="",
        hovermode='x unified',
        plot_bgcolor='white',  # White background
        xaxis=dict(
            showline=True,
            showgrid=True,
            gridcolor='lightgray',  # Light gray grid lines
            linecolor='white',  # Remove border
            linewidth=2,
            zerolinecolor='lightgray'
        ),
        yaxis=dict(
            showline=True,
            showgrid=True,
            gridcolor='lightgray',
            linecolor='white',
            linewidth=2,
            zerolinecolor='lightgray'
        ),
        legend=dict(
            orientation='h',
            yanchor='bottom',
            y=1.02,
            xanchor='right',
            x=1
        ),
        font=dict(
            family='Georgia',  # Update font family (optional)
            size=15,  # Adjust font size
            color='black'  # Font color
        ),
        annotations=[  # Adding the subtitle
            dict(
                text=f'Período: {inicio} à {fim}',  # Subtitle text
                xref='paper', yref='paper',  # Reference to paper (entire figure)
                x=0.00001, y=1.065,  # Position of subtitle (underneath title)
                showarrow=False,  # We don't need an arrow pointing to our subtitle
                font=dict(
                    family='Georgia',
                    size=13,
                    color='gray'  # Gray color for subtitle
                )
            )
        ]
    )
    fig.show()

# %% [markdown]
# ### Plotar retorno dos ativos enquanto na carteira (não ponderado)
#
# Argumentos da função:
# 1. `inicio`: 'YYYY-MM-DD'
# 2. `fim`: 'YYYY-MM-DD'
# 3. `carteira`: *exc*, *hb* ou *lc*

# %%
def plot_ativos(inicio, fim, carteira):

    df = carteira.df_retornos[inicio:fim]

    df_aloc = carteira.df_aloc[inicio:fim]
    df_aloc = df_aloc.map(lambda x: float(x.strip('%')) / 100 if isinstance(x, str) and '%' in x else x)
    df_aloc = df_aloc.fillna(0)
    df_aloc = df_aloc.map(lambda x: 1 if x != 0 else 0)

    df = df.copy().mul(df_aloc)

    df.iloc[0] = 0

    # Excluir ativos que em nenhum momento do período tiveram alocação > 0
    colunas_sem_alocacao = df_aloc.columns[(df_aloc == 0).all(axis=0)]
    df = df.drop(columns=colunas_sem_alocacao, errors='ignore')

    colunas_excluir = df.loc[:, (df == 0).all(axis=0)].columns
    df = df.drop(columns=colunas_excluir)

    df = (1+df).cumprod() - 1

    last_row = df.iloc[-1].sort_values()
    last_row = last_row * 100

    last_row.to_csv('resultado_ativos.csv')

# Define as cores das barras com base nos valores
    colors = ['rgb(255, 99, 71)' if value < 0 else 'rgb(50, 205, 50)' for value in last_row.values]

    hover_texts = [f'Rentabilidade: {value:.2f}%' for index, value in zip(last_row.index, last_row.values)]

    # Plota o gráfico de barras
    fig = go.Figure()

    fig.add_trace(go.Bar(
        x=last_row.index,
        y=last_row.values,
        marker_color=colors,
        marker_line_color='rgb(0,0,0,0)',
        marker_line_width=0.1,
        hoverinfo='y',
        hovertemplate='<b>%{x}</b>: %{y:.2f}%<extra></extra>',
        hoverlabel=dict(
            bgcolor='white',
            font_size=12,
            font_family='Georgia'
        ),
        showlegend=False
    ))


    # Ajustes no layout
    fig.update_layout(
        margin=dict(t=60),
        title={'text': f'{carteira.nome}: performance acumulada dos ativos',
               'x': 0.055,
               'y': 0.97,
               'font': {'size': 18, 'color': 'black', 'family': 'Georgia'}},
        xaxis_title='',
        yaxis_title='Rentabilidade Acumulada (%)',
        plot_bgcolor='white',
        xaxis=dict(
            showline=True,
            showgrid=False,
            linecolor='white',
            linewidth=2,
        ),
        yaxis=dict(
            showline=True,
            showgrid=True,
            gridcolor='lightgray',
            linecolor='white',
            linewidth=2,
            zerolinecolor='lightgray'
        ),
        font=dict(
            family='Georgia',
            size=15,
            color='black'
        ),
        annotations=[
            dict(
                text=f'Período: {inicio} à {fim}',
                xref='paper', yref='paper',
                x=0.0000005, y=1.065,
                showarrow=False,
                font=dict(family='Georgia', size=13, color='gray')
            )
        ]
    )
    fig.show()

# %% [markdown]
# ### Plotar comparação entre carteira e ativos
#
# Argumentos da função:
# **negrito**
# 1. `inicio`: 'YYYY-MM-DD'
# 2. `fim`: 'YYYY-MM-DD'
# 3. `carteira`: *exc*, *hb* ou *lc*

# %%
def plot_carteira_vs_ativos(inicio, fim, carteira):
    # Pegar o DataFrame com os retornos acumulados ponderados
    df = carteira.calcular_retornos_acumulados(inicio, fim, ponderar=False)
    df = df[carteira.calcular_retornos_acumulados(inicio, fim, ponderar=True).columns.intersection(df.columns)]

    # Pegar a última linha do DataFrame (última data) e ordenar
    last_row = df.iloc[-1].sort_values()
    last_row = last_row * 100

    last_row.to_csv(f'{carteira.nome}_resultado_{inicio}_{fim}.csv')

    colors = ['gray' if col != carteira.nome else 'rgb(187,13,49)' for col in last_row.index]

    hover_texts = [f'Rentabilidade: {value:.2f}%' for index, value in zip(last_row.index, last_row.values)]

    # Plota o gráfico de barras
    fig = go.Figure()

    fig.add_trace(go.Bar(
        x=last_row.index,
        y=last_row.values,
        marker_color=colors,
        marker_line_color='rgb(0,0,0,0)',
        marker_line_width=0.1,
        hoverinfo='y',
        hovertemplate='<b>%{x}</b>: %{y:.2f}%<extra></extra>',
        hoverlabel=dict(
            bgcolor='white',
            font_size=12,
            font_family='Georgia'
        ),
        showlegend=False
    ))



    # Ajustes no layout
    fig.update_layout(
        margin=dict(t=60),
        title={'text': f'Performance Acumulada: {carteira.nome} vs. Ativos',
               'x': 0.055,
               'y': 0.97,
               'font': {'size': 18, 'color': 'black', 'family': 'Georgia'}},
        xaxis_title='',
        yaxis_title='Rentabilidade Acumulada (%)',
        plot_bgcolor='white',
        xaxis=dict(
            showline=True,
            showgrid=False,
            linecolor='white',
            linewidth=2,
        ),
        yaxis=dict(
            showline=True,
            showgrid=True,
            gridcolor='lightgray',
            linecolor='white',
            linewidth=2,
            zerolinecolor='lightgray'
        ),
        font=dict(
            family='Georgia',
            size=15,
            color='black'
        ),
        annotations=[
            dict(
                text=f'Período: {inicio} à {fim}',
                xref='paper', yref='paper',
                x=0.0000005, y=1.065,
                showarrow=False,
                font=dict(family='Georgia', size=13, color='gray')
            )
        ]
    )
    fig.show()

# %% [markdown]
# ### Plotar decomposição de retorno acumulado
#
# Argumentos da função:
# 1. `inicio`: 'YYYY-MM-DD'
# 2. `fim`: 'YYYY-MM-DD'
# 3. `carteira`: *exc*, *hb* ou *lc*
# 4. `segmentar`: True ou False (se True, agrega os retornos nas classes BTC, ETH e Alts)
# 5. `Acumular`: True ou False (se True, retorna valorizações acumuladas)

# %%
def plot_decomposicao(inicio, fim, carteira, segmentar=True, acumular=False):

    if acumular:

      df = carteira.calcular_retornos_acumulados(inicio, fim, ponderar=True)
      df = df.drop(columns=[carteira.nome])


    else:

        df = carteira.df_retornos_ponderados[inicio:fim]
        df = df.loc[:, ~(df == 0).all(axis=0)]
        df = df.drop(columns=[carteira.nome])


    df = df.drop(df.index[0])
    df = df * 100




    # Se segmentar for True, agrupe todos os ativos exceto BTC e ETH em Altcoins
    if segmentar:
        # Verifique a existência de BTC e ETH
        btc_exists = 'BTC' in df.columns
        eth_exists = 'ETH' in df.columns

        # Crie a coluna Altcoins somando todos os ativos que não são BTC ou ETH
        altcoins_cols = [col for col in df.columns if col not in ['BTC', 'ETH']]
        df['Altcoins'] = df[altcoins_cols].sum(axis=1)

        # Exclua as colunas originais agora agrupadas em Altcoins
        df = df.drop(columns=altcoins_cols)

        # Reordene as colunas para que Altcoins apareça após BTC e ETH (se existirem)
        order = []
        if btc_exists:
            order.append('BTC')
        if eth_exists:
            order.append('ETH')
        order.append('Altcoins')
        df = df[order]

    if acumular:
        y_titulo = 'Retornos Ponderados e Acumulados (%)'
    else:
        y_titulo = 'Retornos Diários Ponderados (%)'


    titulo = f'Decomposição de Retorno (USD): {carteira.nome}'

    # Inicializa o gráfico
    fig = go.Figure()

    # Adicionar barras ao gráfico para cada coluna (ativo) no DataFrame
    for col in df.columns:
        fig.add_trace(go.Bar(
            x=df.index,
            y=df[col].values,
            name=col,
            hoverinfo='y',
            hovertemplate='<b>' + col + '</b>: %{y:.4f}%<extra></extra>',
            hoverlabel=dict(
                bgcolor='white',
                font_size=12,
                font_family='Georgia'
            ),
            showlegend=True,
            marker=dict(line=dict(width=0))
        ))

    # Ajustes no layout
    fig.update_layout(
        margin=dict(t=60),
        title={
            'text': titulo,
            'x': 0.055,
            'y': 0.97,
            'font': {'size': 18, 'color': 'black', 'family': 'Georgia'}
        },
        xaxis_title='',
        yaxis_title=y_titulo, # mudar
        plot_bgcolor='white',
        xaxis=dict(
            showline=True,
            showgrid=False,
            linecolor='white',
            linewidth=2,
        ),
        yaxis=dict(
            showline=True,
            showgrid=True,
            gridcolor='lightgray',
            linecolor='white',
            linewidth=2,
            zerolinecolor='lightgray'
        ),
        font=dict(
            family='Georgia',
            size=15,
            color='black'
        ),
        annotations=[
            dict(
                text=f'Período: {inicio} à {fim}',
                xref='paper',
                yref='paper',
                x=0.0000005,
                y=1.065,
                showarrow=False,
                font=dict(family='Georgia', size=13, color='gray')
            )
        ],
        barmode='relative'
    )

    # Mostra o gráfico
    fig.show()

# %% [markdown]
# ### Plotar percentual de dias positivos/negativos
#
# Argumentos da função:
# 1. `inicio`: 'YYYY-MM-DD'
# 2. `fim`: 'YYYY-MM-DD'
# 3. `carteira`: *exc*, *hb* ou *lc*
# 4. `segmentar`: True ou False (se True, agrega os retornos nas classes BTC, ETH e Alts)

# %%
def plot_dias_pos_neg(inicio, fim, carteira, segmentar=False):
    # Pegar o DataFrame com as contribuições de retorno
    df = carteira.df_retornos_ponderados[inicio:fim]
    df = df.loc[:, ~(df == 0).all(axis=0)]
    df = df.drop(columns=[carteira.nome])
    df = df.drop(df.index[0])

    if segmentar:
        altcoins = [col for col in df.columns if col not in ['BTC', 'ETH']]
        df['Altcoins'] = df[altcoins].sum(axis=1)
        df.drop(columns=altcoins, inplace=True)

    pos_percents = {}
    neg_percents = {}
    fora_da_carteira_percents = {}

    for col in df.columns:
        pos_count = len(df[df[col] > 0])
        neg_count = len(df[df[col] < 0])
        fora_da_carteira_count = len(df[df[col] == 0])
        total_days = len(df)

        pos_percents[col] = round((pos_count / total_days), 4) * 100
        neg_percents[col] = round((neg_count / total_days), 4) * 100
        fora_da_carteira_percents[col] = round((fora_da_carteira_count / total_days), 4) * 100

    # Inicializa o gráfico
    fig = go.Figure()

    # Adicionar barras de porcentagens

    fig.add_trace(go.Bar(
        x=list(pos_percents.values()),
        y=list(pos_percents.keys()),
        orientation='h',
        name='Dias Positivos (%)',
        marker_color='green',
        hovertemplate='<b>%{y}</b>: %{x: .2f}%<extra></extra>'
    ))
    fig.add_trace(go.Bar(
        x=list(neg_percents.values()),
        y=list(neg_percents.keys()),
        orientation='h',
        name='Dias Negativos (%)',
        marker_color='red',
        hovertemplate='<b>%{y}</b>: %{x: .2f}%<extra></extra>'
    ))
    fig.add_trace(go.Bar(
        x=list(fora_da_carteira_percents.values()),
        y=list(fora_da_carteira_percents.keys()),
        orientation='h',
        name='Fora da Carteira (%)',
        marker_color='lightgray',
        hovertemplate='<b>%{y}</b>: %{x: .0f}%<extra></extra>'
    ))


    # Ajustes no layout
    fig.update_layout(
        margin=dict(t=60),
        title={
            'text': f'Percentual de Dias Positivos/Negativos: {carteira.nome}',
            'x': 0.055,
            'y': 0.97,
            'font': {'size': 18, 'color': 'black', 'family': 'Georgia'}
        },
        xaxis_title='',
        yaxis_title='',
        plot_bgcolor='white',
        xaxis=dict(
            showline=True,
            showgrid=True,
            linecolor='white',
            linewidth=2,

        ),
        yaxis=dict(
            showline=True,
            showgrid=False,
            gridcolor='lightgray',
            linecolor='white',
            linewidth=2,
            zerolinecolor='lightgray'
        ),
        font=dict(
            family='Georgia',
            size=15,
            color='black'
        ),
        annotations=[
            dict(
                text=f'Período: {inicio} à {fim}',
                xref='paper',
                yref='paper',
                x=0.0000005,
                y=1.065,
                showarrow=False,
                font=dict(family='Georgia', size=13, color='gray')
            )
        ],
        barmode='stack'
    )

    # Mostra o gráfico
    fig.show()

# %% [markdown]
# ### Plotar histórico de alocação
#
# Argumentos da função:
# 1. `inicio`: 'YYYY-MM-DD'
# 2. `fim`: 'YYYY-MM-DD'
# 3. `carteira`: *exc*, *hb* ou *lc*
# 4. `segmentar`: True ou False (se True, agrega os retornos nas classes BTC, ETH e Alts)
# 5. `real_aloc`: True ou False (se True, simula alocações sem rebalanceamento diário)

# %%
def plot_alocacoes(inicio, fim, carteira, segmentar=False, real_aloc=False):
    # Pegar o DataFrame com as alocações

    if real_aloc:
      df = carteira.df_aloc_balanceada_alerta[inicio:fim]
    else:
      df = carteira.df_aloc[inicio:fim]
      df = df.map(lambda x: float(x.strip('%')) / 100 if isinstance(x, str) and '%' in x else x) # por cause que o df de alocações vem em percentual, do sheets

    df = df.loc[:, ~(df == 0).all(axis=0)]
    df = df * 100

    # Se segmentar for True, faça as alterações necessárias
    if segmentar:
        # Agrupe 'USDT', 'BUSD' e 'TUSD' em 'Caixa' se estiverem no DataFrame
        caixa_cols = ['USDT', 'BUSD', 'TUSD']
        caixa_presentes = [col for col in caixa_cols if col in df.columns]
        if caixa_presentes:
            df['Caixa'] = df[caixa_presentes].sum(axis=1)
            df = df.drop(columns=caixa_presentes)

        # Agrupe todos os ativos exceto 'BTC', 'ETH' e 'Caixa' em 'Altcoins'
        altcoins_cols = [col for col in df.columns if col not in ['BTC', 'ETH', 'Caixa']]
        if altcoins_cols:
            df['Altcoins'] = df[altcoins_cols].sum(axis=1)
            df = df.drop(columns=altcoins_cols)

    # Inicializa o gráfico
    fig = go.Figure()

    # Adicione barras ao gráfico para cada coluna (ativo) no DataFrame
    for col in df.columns:
        fig.add_trace(go.Bar(
            x=df.index,
            y=df[col].values,
            name=col,
            hovertemplate='<b>' + col + '</b>: %{y:.0f}%<extra></extra>',
            marker=dict(line=dict(width=0))
        ))

    # Ajustes no layout
    fig.update_layout(
        margin=dict(t=60),
        title={
            'text': f'Alocação de Ativos ao Longo do Tempo: {carteira.nome}',
            'x': 0.055,
            'y': 0.97,
            'font': {'size': 18, 'color': 'black', 'family': 'Georgia'}
        },
        xaxis_title='',
        yaxis_title='Alocação (%)',
        plot_bgcolor='white',
        bargap=0,
        xaxis=dict(
            showline=True,
            showgrid=False,
            linecolor='white',
            linewidth=0,
            tickangle=-45, # rotacionar rótulos do eixo X
            nticks=20 # limita a quantidade de ticks no eixo X
        ),
        yaxis=dict(
            showline=False,
            showgrid=False,
            gridcolor='lightgray',
            linecolor='white',
            linewidth=2,
            zerolinecolor='lightgray'
        ),
        font=dict(
            family='Georgia',
            size=15,
            color='black'
        ),
        annotations=[
            dict(
                text=f'Período: {inicio} à {fim}',
                xref='paper',
                yref='paper',
                x=0.0000005,
                y=1.065,
                showarrow=False,
                font=dict(family='Georgia', size=13, color='gray')
            )
        ],
        barmode='stack'
    )

    # Mostra o gráfico
    fig.show()

# %% [markdown]
# ### Plotar Value At Risk e Value of Oportunity
#
# *-- Value at Risk (VaR):*
#
# **Definição**: O VaR é uma medida estatística que estima o risco máximo de perda financeira que um portfólio de investimentos pode sofrer em um determinado período de tempo, dado um nível específico de confiança.
#
# *-- Value of Opportunity:*
#
# **Definição**: Embora não seja um termo padrão como o VaR, "Value of Opportunity" pode ser entendido como o inverso do VaR. Em vez de focar nas perdas potenciais, ele foca nos ganhos potenciais.
#
# <br></br>
# Argumentos da função:
# 1. `carteira`: *exc*, *hb* ou *lc*
# 2. `janela_amostral`: quantidade de dias passados que será levado em conta na estatística
# 3. `nivel_confianca`: nível de confiança (padrão é 95%)
# 4. `periodo`: periodo para estimativa futura em dias (precisa ser <= `janela_amostral`)
# 5. `filtrar_atuais`: True ou False (se True, inclue somente ativos atualmente na carteira; se False, todos os ativos que já fizeram parte da carteira)

# %%
def plot_var_voo(carteira, janela_amostral=90, nivel_confianca=95, periodo=7, filtrar_atuais=False):
    # Cortar a planilha de alocações para a janela de amostral
    df_aloc_cortada = carteira.df_aloc.tail(janela_amostral)
    df_aloc_cortada = df_aloc_cortada.map(lambda x: float(x.strip('%')) / 100 if isinstance(x, str) and '%' in x else x)

    colunas_para_excluir = ["USDT", "BUSD", "TUSD"]

    if filtrar_atuais:
        # Obter o último registro de alocação e verificar quais ativos têm alocação diferente de zero
        ativos_atualmente = df_aloc_cortada.tail(1)
        ativos_atualmente = ativos_atualmente.loc[:, (ativos_atualmente != 0).any(axis=0)]
        # Filtrar esses ativos no DataFrame de retornos e excluir os indesejados
        df_retornos_filtrados = carteira.df_retornos[ativos_atualmente.columns].drop(columns=colunas_para_excluir, errors='ignore')
    else:
        # Utilizar todos os ativos da carteira.df_retornos excluindo as colunas indesejadas
        df_retornos_filtrados = carteira.df_retornos.drop(columns=colunas_para_excluir, errors='ignore')



    # Calcular VaR e VoO para cada ativo
    var_values = []
    voo_values = []
    ativos = []

    ativos_diferenca = []

    for ativo in df_retornos_filtrados.columns:
        try:
            var = carteira.calcular_var_historico(ativo, nivel_confianca, janela_amostral, periodo)
            voo = carteira.calcular_voo_historico(ativo, nivel_confianca, janela_amostral, periodo)
            ativos_diferenca.append((ativo, var, voo))
        except ValueError:
            # Ignora ativos que não estão presentes na carteira
            continue

    # Ordenar pela diferença entre VoO e VaR (ordem decrescente de diferencial)
    ativos_diferenca.sort(key=lambda x: x[2] + x[1], reverse=True)

    # Desempacotar os ativos e valores após a ordenação
    ativos, var_values, voo_values = zip(*ativos_diferenca)
    # Plota o gráfico de barras
    fig = go.Figure()

    # Adicionar barras para o VaR
    fig.add_trace(go.Bar(
        x=ativos,
        y=var_values,
        name='VaR',
        marker_color='rgb(255, 99, 71)',
        hoverinfo='y',
        hovertemplate='<b>' + 'VaR' + '</b>: %{y:.2f}%<extra></extra>',
    ))

    # Adicionar barras para o VoO
    fig.add_trace(go.Bar(
        x=ativos,
        y=voo_values,
        name='VoO',
        marker_color='rgb(50, 205, 50)',
        hoverinfo='y',
        hovertemplate='<b>' + 'VoO' + '</b>: %{y:.2f}%<extra></extra>',
    ))

    # Encontrar o valor mínimo e máximo para definir o range do eixo y
    min_value = min(min(var_values), min(voo_values)) * 1.1
    max_value = max(max(var_values), max(voo_values)) * 1.1

    # Ajustes no layout, incluindo anotação com parâmetros utilizados
    fig.update_layout(
        barmode='relative',
        title={'text': f'Risco x Oportunidade (VaR x VoO): {carteira.nome}',
               'x': 0.5,
               'y': 0.95,
               'font': {'size': 18, 'color': 'black', 'family': 'Georgia'}},
        xaxis_title='',
        yaxis_title='Percentual (%)',
        plot_bgcolor='white',
        xaxis=dict(
            showline=True,
            showgrid=False,
            linecolor='black',
            linewidth=2,
        ),
        yaxis=dict(
            showline=True,
            showgrid=True,
            gridcolor='lightgray',
            linecolor='black',
            linewidth=2,
            zeroline=True,
            zerolinewidth=2,
            zerolinecolor='black',
            range=[min_value, max_value]
        ),
        font=dict(
            family='Georgia',
            size=15,
            color='black'
        ),
        annotations=[
            dict(
                x=0.01,
                y=1.2,
                showarrow=False,
                text=f"<br>Janela Amostral: {janela_amostral} dias<br>"
                     f"Nível de Confiança: {nivel_confianca}%<br>"
                     f"Período: {periodo} dias",
                xref="paper",
                yref="paper",
                align="left",
                bordercolor="black",
                borderwidth=1,
                borderpad=4,
                bgcolor="white",
                font=dict(
                    family="Georgia",
                    size=12,
                    color="black"
                )
            )
        ]
    )

    # Exibe o gráfico
    fig.show()

# %% [markdown]
# ### Plotar matriz de correlação
#
# Argumentos da função:
# 1. `carteira`: *exc*, *hb* ou *lc*
# 2. `janela_amostral`: quantidade de dias passados que será levado em conta na estatística
# 3. `filtrar_atuais`: True ou False (se True, inclue somente ativos atualmente na carteira; se False, todos os ativos que já fizeram parte da carteira)
# 4. `setorizar`: True ou False (se True, agrega os ativos em narrativas com base na planilha de categorias)

# %%
def plot_correlation_matrix(carteira, janela_amostral=30, filtrar_atuais=False, setorizar=False):

    carteira.df_aloc=carteira.df_aloc.map(lambda x: float(x.strip('%')) / 100 if isinstance(x, str) and '%' in x else x)

    if filtrar_atuais:
        ativos_atualmente = carteira.df_aloc.tail(1)
        ativos_atualmente = ativos_atualmente.loc[:, (ativos_atualmente != 0).any(axis=0)]
        df_retornos_filtrados = carteira.df_retornos[ativos_atualmente.columns]

    else:
        df_retornos_filtrados = carteira.df_retornos

    colunas_para_excluir = ["USDT", "BUSD", "TUSD"]
    df_retornos_filtrados = df_retornos_filtrados.drop(columns=colunas_para_excluir, errors='ignore')


    if setorizar:

        if not hasattr(carteira, 'df_cats'):
            raise ValueError("A carteira não possui o atributo 'df_cats' necessário para setorizar.")


        df_cats = carteira.df_cats
        retornos_por_categoria = {}

        for categoria in df_cats['categoria'].unique():
            ativos_na_categoria = df_cats[df_cats['categoria'] == categoria]['ativo']
            ativos_na_categoria = [ativo for ativo in ativos_na_categoria if ativo in df_retornos_filtrados.columns]

            # Calcular o retorno médio para a categoria
            if ativos_na_categoria:
                retornos_por_categoria[categoria] = df_retornos_filtrados[ativos_na_categoria].median(axis=1)


        df_retornos_filtrados = pd.DataFrame(retornos_por_categoria)



    df_retornos_filtrados=df_retornos_filtrados.copy().tail(janela_amostral)



    corr_matrix = df_retornos_filtrados.corr()


    # Criar o gráfico de calor para a matriz de correlação
    fig = go.Figure(data=go.Heatmap(
        z=corr_matrix.values,
        x=corr_matrix.columns,
        y=corr_matrix.index,
        colorscale='Viridis',
        colorbar=dict(title='Correlação'),
    ))

    # Ajustes no layout
    fig.update_layout(
        title={'text': f'Matriz de Correlação de {janela_amostral} dias - {carteira.nome}',
               'x': 0.5,
               'y': 0.95,
               'xanchor': 'center',
               'yanchor': 'top'},
        xaxis_title='',
        yaxis_title='',
        xaxis=dict(tickangle=-45),
        yaxis=dict(tickangle=45),
        font=dict(
            family='Georgia',
            size=12,
            color='black'
        ),
        hovermode='closest',
    )

    # Exibe o gráfico
    fig.show()

# %% [markdown]
# ### Plotar alocações por ativo ao longo do tempo
#
# Essa função funciona plota um Gantt Chart que mostra entradas e saídas de ativos ao longo do tempo em uma carteira.
#
# Argumentos da função:
# 1. `carteira`: *exc*, *hb* ou *lc*

# %%
import plotly.express as px
import pandas as pd

def posicoes(carteira):

    df_aloc = carteira.df_aloc.map(lambda x: float(x.strip('%')) / 100 if isinstance(x, str) and '%' in x else x)

    tasks = []
    for ativo in df_aloc.columns:
        # Encontrar os períodos em que o ativo está na carteira
        in_portfolio = df_aloc[ativo] != 0
        starts = df_aloc.index[in_portfolio & (~in_portfolio.shift(1, fill_value=False))].tolist()
        ends = df_aloc.index[in_portfolio & (~in_portfolio.shift(-1, fill_value=False))].tolist()

        # Se o ativo está na carteira desde o início, adicione a primeira data como início
        if in_portfolio.iloc[0]:
            starts.insert(0, df_aloc.index[0])

        # Se o ativo está na carteira no final, adicione a última data como fim
        if in_portfolio.iloc[-1]:
            ends.append(df_aloc.index[-1])

        # Adicionar os períodos ao conjunto de tarefas
        tasks += [{'Ativo': ativo, 'Start': s, 'Finish': e} for s, e in zip(starts, ends)]

    df_tasks = pd.DataFrame(tasks)

    # Criar o gráfico de Gantt
    fig = px.timeline(df_tasks, x_start="Start", x_end="Finish", y="Ativo", labels={'Ativo':'Ativos'})


    altura_por_ativo = 30
    altura_total = altura_por_ativo * len(df_aloc.columns)

    # Ajustar o layout para corresponder à estética desejada e definir a altura dinâmica
    fig.update_layout({
        'title': 'Posições dos Ativos ao Longo do Tempo',
        'xaxis_title': 'Data',
        'yaxis_title': '',
        'showlegend': False,
        'plot_bgcolor': 'white',
        'font': dict(family="Georgia", size=15, color="black"),
        'xaxis': {
            'showline': True,
            'showgrid': False,
            'linecolor': 'black',
            'linewidth': 2
        },
        'yaxis': {
            'showgrid': True,
            'gridcolor': 'lightgray',
            'showline': True,
            'linecolor': 'black',
            'linewidth': 2
        },
        'height': altura_total  # Define a altura dinamicamente
    })

    # Exibir o gráfico
    fig.show()

# %% [markdown]
# ## Setup inicial
#
# Abaixo são definidas os ativos em cada carteira e importadas as planilhas de alocação.
#
# #### Para adicionar um ativo novo:
#
# 1. Procurar pelo ativo no CoinGecko (i.e. https://www.coingecko.com/pt/moedas/dogwifhat)
# 2. Na página do ativo, localizar o id de API (i.e. 'dogwifcoin')
# 3. Adicionar o ativo na lista da carteira respectiva
# 4. Adicionar uma nova coluna com o **ticker** do ativo na planilha da carteira respectiva, e preencher as alocações com 0 até o dia da primeira alocação.
#
#
# [Link das planilhas aqui!](https://docs.google.com/spreadsheets/d/1156S3pm9vQ2JP5bE0yvpj_Y8FE55ecovHS_JvIys5dc)
#
# #### Para retirar um ativo:
#
# 1. Basta zerar a posição do ativo na planilha de alocações.

# %%
# ==========================================
# Definicao das Carteiras e Carregamento de Dados
# ==========================================

carteira_EXC = ['aave', 'arbitrum', 'arweave','audius','aurory','avalanche-2','axie-infinity','balancer','band-protocol','binancecoin','bitcoin-cash','cardano',
                'eos','litecoin','polkadot','ripple','bitcoin','curve-dao-token','tether','true-usd','chainlink','compound-governance-token','cosmos','crypto-com-chain',
                'dash','decentraland', 'dodo', 'dydx','ethereum', 'ethereum-classic', 'fantom', 'flow', 'gmx', 'stellar', 'havven', 'helium', 'internet-computer',
                'kyber-network-crystal', 'lido-dao','lisk', 'maker', 'matic-network', 'monero', 'polymath', 'near', 'omisego', 'optimism', 'pancakeswap-token', 'pax-gold',
                'pendle', 'star-atlas-dao', 'ronin', 'rari-governance-token', 'the-sandbox', 'secret', 'serum', 'smartcash', 'solana', 'spell-token', 'sushi', 'swarm',
                'terra-luna-2', 'tezos', 'tribe-2', 'uniswap', 'wibx', 'wrapped-nxm', 'yearn-finance', 'zcash', 'frax-share', 'celestia', 'ronin', 'thorchain', 'immutable-x',
                'akash-network', 'render-token', 'blockstack', 'ondo-finance', 'the-open-network', 'aerodrome-finance', 'morpho', 'ethena', 'virtual-protocol','hyperliquid',
                'bittensor','sui', 'fetch-ai', 'syrup', 'sei-network','euler']


carteira_HB = ['ethereum', 'tether', 'maker', 'havven', 'aave', 'uniswap', 'dydx',
              'cosmos', 'secret', 'the-sandbox', 'helium', 'matic-network',
              'near', 'decentraland',
              'curve-dao-token', 'gmx', 'optimism',
              'gala', 'flow', 'lido-dao', 'frax-share', 'numeraire',
              'gains-network', 'injective-protocol', 'arbitrum', 'pendle', 'radiant-capital',
              'chainlink', 'solana', 'avalanche-2', 'kujira', 'echelon-prime', 'akash-network', 'render-token', 'beam-2', 'multibit',
              'ondo-finance', 'ether-fi', 'aerodrome-finance', 'morpho', 'virtual-protocol', 'ethena', 'curve-dao-token', 'deep', 'raydium', 'syrup', 'euler',
              'moonwell-artemis', 'aioz-network','zebec-network', 'liquity', 'zcash']


carteira_LC = ['arweave', 'badger-dao', 'my-neighbor-alice', 'perpetual-protocol',
              'alpha-finance', 'yield-guild-games', 'genopets', 'acala','rainbow-token-2',
              'guild-of-guardians', 'aurory', 'illuvium', 'conic-finance', 'vela-token',
              'radiant-capital', 'botto', 'pendle', 'nunet', 'kryptonite', 'prisma-governance-token',
              'genesysgo-shadow', 'neon', 'mintlayer', 'ethervista', 'heyanon', 'yne', 'kamino', 'griffain', 'metacade', 'myria', 'mamo',
              'meta-2-2','bertram-the-pomeranian', 'avici', 'umbra']

carteira_AC = ['bitcoin', 'ethereum', 'solana', 'maker', 'chainlink', 'thorchain', 'blockstack', 'immutable-x', 'uniswap', 'pendle', 'aave',
               'ethervista', 'morpho', 'ethena', 'virtual-protocol', 'ondo-finance', 'yne', 'tether', 'bittensor', 'curve-dao-token', 'render-token', 'griffain', 'sui', 'fetch-ai', 'ether-fi',
               'hyperliquid', 'sei-network', 'liquity', 'aerodrome-finance', 'syrup', 'zcash', 'pax-gold']


# ==========================================
# Funcoes de Carregamento de CSV Local
# ==========================================

def load_csv_allocation(filepath):
    df = pd.read_csv(
        filepath,
        encoding='utf-8',
        index_col='Data',
        parse_dates=['Data'],
        date_format='%Y-%m-%d'
    )
    return df


def load_categories(filepath):
    df = pd.read_csv(
        filepath,
        encoding='utf-8',
        index_col='Data' if 'Data' in pd.read_csv(filepath, nrows=0).columns else None,
        parse_dates=['Data'] if 'Data' in pd.read_csv(filepath, nrows=0).columns else False
    )
    return df


# ==========================================
# Carregamento dos Dados Locais
# ==========================================

print("Carregando alocacoes dos arquivos CSV locais...")

exc_aloc = load_csv_allocation(ALLOCATIONS_DIR / "EXC.csv")
print(f"  EXC: {len(exc_aloc)} linhas, {len(exc_aloc.columns)} colunas")

hb_aloc = load_csv_allocation(ALLOCATIONS_DIR / "HB.csv")
print(f"  HB: {len(hb_aloc)} linhas, {len(hb_aloc.columns)} colunas")

lc_aloc = load_csv_allocation(ALLOCATIONS_DIR / "LC.csv")
print(f"  LC: {len(lc_aloc)} linhas, {len(lc_aloc.columns)} colunas")

ac_aloc = load_csv_allocation(ALLOCATIONS_DIR / "AC.csv")
print(f"  AC: {len(ac_aloc)} linhas, {len(ac_aloc.columns)} colunas")

cats = load_categories(CATEGORIES_DIR / "CATS.csv")
print(f"  CATS: {len(cats)} linhas, {len(cats.columns)} colunas")

print("Todos os dados carregados com sucesso!")
# Out:
# Carregando alocacoes dos arquivos CSV locais...
#   EXC: 3055 linhas, 89 colunas
#   HB: 1232 linhas, 51 colunas
#   LC: 1628 linhas, 35 colunas
#   AC: 562 linhas, 31 colunas
#   CATS: 99 linhas, 2 colunas
# Todos os dados carregados com sucesso!

# %% [markdown]
# ## Instanciando as carteiras
#
# Abaixo, criamos as intâncias de cada carteira de acordo com os requerimentos da classe `PortfolioCrypto()`.
#
#
# Ao rodar esse código, o script vai primeiramente atualizar os preços de todos os ativos, em cada pasta individual. É possível implementar um cron job para automatizar esse processo.

# %%
# %%time

exc = PortfolioCrypto(carteira='EXC',
                      ativos=carteira_EXC,
                      aloc=exc_aloc,
                      categorias=cats)

ac = PortfolioCrypto(carteira='Alphacoins',
                      ativos=carteira_AC,
                      aloc=ac_aloc,
                      categorias=cats)

hb = PortfolioCrypto(carteira='High Beta',
                     ativos=carteira_HB,
                     aloc=hb_aloc,
                     categorias=cats)

lc = PortfolioCrypto(carteira='Low Caps',
                     ativos=carteira_LC,
                     aloc=lc_aloc,
                     categorias=cats)
# Out:
# Processando 1 de 90: aave
# Processando 2 de 90: arbitrum
# Processando 3 de 90: arweave
# Processando 4 de 90: audius
# Processando 5 de 90: aurory
# Processando 6 de 90: avalanche-2
# Processando 7 de 90: axie-infinity
# Processando 8 de 90: balancer
# Processando 9 de 90: band-protocol
# Processando 10 de 90: binancecoin
# Processando 11 de 90: bitcoin-cash
# Processando 12 de 90: cardano
# Processando 13 de 90: eos
# Processando 14 de 90: litecoin
# Processando 15 de 90: polkadot
# Processando 16 de 90: ripple
# Processando 17 de 90: bitcoin
# Processando 18 de 90: curve-dao-token
# Processando 19 de 90: tether
# Processando 20 de 90: true-usd
# Processando 21 de 90: chainlink
# Processando 22 de 90: compound-governance-token
# Processando 23 de 90: cosmos
# Processando 24 de 90: crypto-com-chain
# Processando 25 de 90: dash
# Processando 26 de 90: decentraland
# Processando 27 de 90: dodo
# Processando 28 de 90: dydx
# Processando 29 de 90: ethereum
# Processando 30 de 90: ethereum-classic
# Processando 31 de 90: fantom
# Processando 32 de 90: flow
# Processando 33 de 90: gmx
# Processando 34 de 90: stellar
# Processando 35 de 90: havven
# Processando 36 de 90: helium
# Processando 37 de 90: internet-computer
# Processando 38 de 90: kyber-network-crystal
# Processando 39 de 90: lido-dao
# Processando 40 de 90: lisk
# Processando 41 de 90: maker
# Processando 42 de 90: matic-network
# Processando 43 de 90: monero
# Processando 44 de 90: polymath
# Processando 45 de 90: near
# Processando 46 de 90: omisego
# Processando 47 de 90: optimism
# Processando 48 de 90: pancakeswap-token
# Processando 49 de 90: pax-gold
# Processando 50 de 90: pendle
# Processando 51 de 90: star-atlas-dao
# Processando 52 de 90: ronin
# Processando 53 de 90: rari-governance-token
# Processando 54 de 90: the-sandbox
# Processando 55 de 90: secret
# Processando 56 de 90: serum
# Processando 57 de 90: smartcash
# Processando 58 de 90: solana
# Processando 59 de 90: spell-token
# Processando 60 de 90: sushi
# Processando 61 de 90: swarm
# Processando 62 de 90: terra-luna-2
# Processando 63 de 90: tezos
# Processando 64 de 90: tribe-2
# Processando 65 de 90: uniswap
# Processando 66 de 90: wibx
# Processando 67 de 90: wrapped-nxm
# Processando 68 de 90: yearn-finance
# Processando 69 de 90: zcash
# Processando 70 de 90: frax-share
# Processando 71 de 90: celestia
# Processando 72 de 90: ronin
# ronin OK!
# Processando 73 de 90: thorchain
# Processando 74 de 90: immutable-x
# Processando 75 de 90: akash-network
# Processando 76 de 90: render-token
# Processando 77 de 90: blockstack
# Processando 78 de 90: ondo-finance
# Processando 79 de 90: the-open-network
# Processando 80 de 90: aerodrome-finance
# Processando 81 de 90: morpho
# Processando 82 de 90: ethena
# Processando 83 de 90: virtual-protocol
# Processando 84 de 90: hyperliquid
# Processando 85 de 90: bittensor
# Processando 86 de 90: sui
# Processando 87 de 90: fetch-ai
# Processando 88 de 90: syrup
# Processando 89 de 90: sei-network
# Processando 90 de 90: euler
# Initial df_posicao:
#  BTC      10000.0
# ETH          0.0
# BCH          0.0
# XRP          0.0
# LTC          0.0
#           ...
# SUI          0.0
# FET          0.0
# SYRUP        0.0
# SEI          0.0
# EUL          0.0
# Name: 2017-10-02 00:00:00, Length: 88, dtype: object
# Processando 1 de 32: bitcoin
# bitcoin OK!
# Processando 2 de 32: ethereum
# ethereum OK!
# Processando 3 de 32: solana
# solana OK!
# Processando 4 de 32: maker
# maker OK!
# Processando 5 de 32: chainlink
# chainlink OK!
# Processando 6 de 32: thorchain
# thorchain OK!
# Processando 7 de 32: blockstack
# blockstack OK!
# Processando 8 de 32: immutable-x
# immutable-x OK!
# Processando 9 de 32: uniswap
# uniswap OK!
# Processando 10 de 32: pendle
# pendle OK!
# Processando 11 de 32: aave
# aave OK!
# Processando 12 de 32: ethervista
# Processando 13 de 32: morpho
# morpho OK!
# Processando 14 de 32: ethena
# ethena OK!
# Processando 15 de 32: virtual-protocol
# virtual-protocol OK!
# Processando 16 de 32: ondo-finance
# ondo-finance OK!
# Processando 17 de 32: yne
# Processando 18 de 32: tether
# tether OK!
# Processando 19 de 32: bittensor
# bittensor OK!
# Processando 20 de 32: curve-dao-token
# curve-dao-token OK!
# Processando 21 de 32: render-token
# render-token OK!
# Processando 22 de 32: griffain
# Processando 23 de 32: sui
# sui OK!
# Processando 24 de 32: fetch-ai
# fetch-ai OK!
# Processando 25 de 32: ether-fi
# Processando 26 de 32: hyperliquid
# hyperliquid OK!
# Processando 27 de 32: sei-network
# sei-network OK!
# Processando 28 de 32: liquity
# Processando 29 de 32: aerodrome-finance
# aerodrome-finance OK!
# Processando 30 de 32: syrup
# syrup OK!
# Processando 31 de 32: zcash
# zcash OK!
# Processando 32 de 32: pax-gold
# pax-gold OK!
# Initial df_posicao:
#  BTC        5000.0
# ETH        1500.0
# SOL        1500.0
# MKR         300.0
# LINK        300.0
# RUNE        300.0
# STX         300.0
# IMX         300.0
# UNI         200.0
# PENDLE      300.0
# AAVE          0.0
# VISTA         0.0
# MORPHO        0.0
# ENA           0.0
# VIRTUAL       0.0
# ONDO          0.0
# YNE           0.0
# USDT          0.0
# TAO           0.0
# CRV           0.0
# RENDER        0.0
# SUI           0.0
# FET           0.0
# ETHFI         0.0
# HYPE          0.0
# SEI           0.0
# LQTY          0.0
# AERO          0.0
# SYRUP         0.0
# PAXG          0.0
# ZEC           0.0
# Name: 2024-07-30 00:00:00, dtype: object
# Processando 1 de 52: ethereum
# ethereum OK!
# Processando 2 de 52: tether
# tether OK!
# Processando 3 de 52: maker
# maker OK!
# Processando 4 de 52: havven
# havven OK!
# Processando 5 de 52: aave
# aave OK!
# Processando 6 de 52: uniswap
# uniswap OK!
# Processando 7 de 52: dydx
# dydx OK!
# Processando 8 de 52: cosmos
# cosmos OK!
# Processando 9 de 52: secret
# secret OK!
# Processando 10 de 52: the-sandbox
# the-sandbox OK!
# Processando 11 de 52: helium
# helium OK!
# Processando 12 de 52: matic-network
# Processando 13 de 52: near
# near OK!
# Processando 14 de 52: decentraland
# decentraland OK!
# Processando 15 de 52: curve-dao-token
# curve-dao-token OK!
# Processando 16 de 52: gmx
# gmx OK!
# Processando 17 de 52: optimism
# optimism OK!
# Processando 18 de 52: gala
# Processando 19 de 52: flow
# flow OK!
# Processando 20 de 52: lido-dao
# lido-dao OK!
# Processando 21 de 52: frax-share
# frax-share OK!
# Processando 22 de 52: numeraire
# Processando 23 de 52: gains-network
# Processando 24 de 52: injective-protocol
# Processando 25 de 52: arbitrum
# arbitrum OK!
# Processando 26 de 52: pendle
# pendle OK!
# Processando 27 de 52: radiant-capital
# Processando 28 de 52: chainlink
# chainlink OK!
# Processando 29 de 52: solana
# solana OK!
# Processando 30 de 52: avalanche-2
# avalanche-2 OK!
# Processando 31 de 52: kujira
# Processando 32 de 52: echelon-prime
# Processando 33 de 52: akash-network
# akash-network OK!
# Processando 34 de 52: render-token
# render-token OK!
# Processando 35 de 52: beam-2
# Processando 36 de 52: multibit
# Processando 37 de 52: ondo-finance
# ondo-finance OK!
# Processando 38 de 52: ether-fi
# ether-fi OK!
# Processando 39 de 52: aerodrome-finance
# aerodrome-finance OK!
# Processando 40 de 52: morpho
# morpho OK!
# Processando 41 de 52: virtual-protocol
# virtual-protocol OK!
# Processando 42 de 52: ethena
# ethena OK!
# Processando 43 de 52: curve-dao-token
# curve-dao-token OK!
# Processando 44 de 52: deep
# Processando 45 de 52: raydium
# Processando 46 de 52: syrup
# syrup OK!
# Processando 47 de 52: euler
# euler OK!
# Processando 48 de 52: moonwell-artemis
# Processando 49 de 52: aioz-network
# Processando 50 de 52: zebec-network
# Processando 51 de 52: liquity
# liquity OK!
# Processando 52 de 52: zcash
# zcash OK!
# Initial df_posicao:
#  ETH        1500.0
# USDT          0.0
# MKR         250.0
# SNX         250.0
# AAVE        500.0
# UNI        1000.0
# ETHDYDX     500.0
# ATOM        750.0
# SCRT        250.0
# SAND        500.0
# HNT         500.0
# MATIC      1250.0
# NEAR        250.0
# MANA        500.0
# CRV         500.0
# GMX         500.0
# OP          500.0
# GALA        250.0
# FLOW        250.0
# LDO           0.0
# NMR           0.0
# GNS           0.0
# INJ           0.0
# ARB           0.0
# PENDLE        0.0
# RDNT          0.0
# SOL           0.0
# LINK          0.0
# AVAX          0.0
# KUJI          0.0
# PRIME         0.0
# AKT           0.0
# RENDER        0.0
# BEAM          0.0
# MUBI          0.0
# ONDO          0.0
# ETHFI         0.0
# AERO          0.0
# MORPHO        0.0
# VIRTUAL       0.0
# ENA           0.0
# DEEP          0.0
# RAY           0.0
# SYRUP         0.0
# EUL           0.0
# WELL          0.0
# AIOZ          0.0
# ZBCN          0.0
# LQTY          0.0
# ZEC           0.0
# Name: 2022-09-29 00:00:00, dtype: object
# Processando 1 de 35: arweave
# arweave OK!
# Processando 2 de 35: badger-dao
# Processando 3 de 35: my-neighbor-alice
# Processando 4 de 35: perpetual-protocol
# Processando 5 de 35: alpha-finance
# Processando 6 de 35: yield-guild-games
# Processando 7 de 35: genopets
# Processando 8 de 35: acala
# Processando 9 de 35: rainbow-token-2
# Processando 10 de 35: guild-of-guardians
# Processando 11 de 35: aurory
# aurory OK!
# Processando 12 de 35: illuvium
# Processando 13 de 35: conic-finance
# Processando 14 de 35: vela-token
# Processando 15 de 35: radiant-capital
# radiant-capital OK!
# Processando 16 de 35: botto
# Processando 17 de 35: pendle
# pendle OK!
# Processando 18 de 35: nunet
# Processando 19 de 35: kryptonite
# Processando 20 de 35: prisma-governance-token
# Processando 21 de 35: genesysgo-shadow
# Processando 22 de 35: neon
# Processando 23 de 35: mintlayer
# Processando 24 de 35: ethervista
# ethervista OK!
# Processando 25 de 35: heyanon
# Processando 26 de 35: yne
# yne OK!
# Processando 27 de 35: kamino
# Processando 28 de 35: griffain
# griffain OK!
# Processando 29 de 35: metacade
# Processando 30 de 35: myria
# Processando 31 de 35: mamo
# Processando 32 de 35: meta-2-2
# Processando 33 de 35: bertram-the-pomeranian
# Processando 34 de 35: avici
# Processando 35 de 35: umbra
# Initial df_posicao:
#  AR          2000.0
# BADGER      2000.0
# ALICE       2000.0
# PERP        2000.0
# ALPHA       2000.0
# YGG            0.0
# GENE           0.0
# ACA            0.0
# RBW            0.0
# GOG            0.0
# AURY           0.0
# ILV            0.0
# CNC            0.0
# RDNT           0.0
# BOTTO          0.0
# PENDLE         0.0
# NTX            0.0
# SEILOR         0.0
# PRISMA         0.0
# SHDW           0.0
# NEON           0.0
# ML             0.0
# VISTA          0.0
# ANON           0.0
# YNE            0.0
# GRIFFAIN       0.0
# KMNO           0.0
# MCADE          0.0
# MYRIA          0.0
# MAMO           0.0
# META           0.0
# BERT           0.0
# AVICI          0.0
# UMBRA          0.0
# Name: 2021-08-29 00:00:00, dtype: object
# CPU times: total: 21 s
# Wall time: 1min 55s

# %% [markdown]
# # Diagnóstico de carteiras

# %%
ac.posicoes_fechadas().sort_values(by=['data_saida'], ascending=False)
# Out:
#       ativo data_entrada data_saida  dias_em_carteira  preco_entrada  \
# 30  VIRTUAL   2025-01-13 2026-01-31               383        2.65357
# 27      ZEC   2025-11-18 2026-01-31                74      623.30817
# 26      SOL   2025-09-09 2026-01-31               144      217.38519
# 9       ETH   2025-05-23 2026-01-31               253     2519.81381
# 7      PAXG   2025-11-18 2025-12-08                20     4062.83309
# 16    ETHFI   2025-05-17 2025-11-18               185        1.24121
# 25      ENA   2025-07-31 2025-11-18               110        0.56952
# 28   PENDLE   2025-08-23 2025-11-03                72        6.09214
# 3      AERO   2025-07-01 2025-11-03               125        0.74770
# 21     LINK   2025-08-23 2025-11-03                72       26.28092
# 24     LQTY   2025-06-28 2025-09-23                87        1.43000
# 8       SEI   2025-06-28 2025-07-31                33        0.29171
# 12    SYRUP   2025-07-09 2025-07-22                13        0.52589
# 15      SOL   2024-07-30 2025-06-21               326      179.03919
# 10      SUI   2025-04-25 2025-06-03                39        3.50670
# 2       FET   2025-05-07 2025-06-03                27        0.67697
# 20   MORPHO   2024-12-07 2025-05-31               175        2.22374
# 1       TAO   2025-04-23 2025-05-31                38      336.80609
# 5    RENDER   2025-04-23 2025-05-20                27        4.47433
# 6       CRV   2025-04-23 2025-05-17                24        0.65113
# 11   PENDLE   2024-07-30 2025-05-07               281        3.68654
# 22     ONDO   2025-01-30 2025-05-03                93        1.56458
# 29      ENA   2024-12-18 2025-04-23               126        1.08212
# 4      LINK   2024-07-30 2025-04-23               267       13.13789
# 14      UNI   2024-07-30 2025-04-23               267        7.38960
# 23      ETH   2024-07-30 2025-04-23               267     3276.98178
# 0      AAVE   2024-09-05 2025-04-23               230      129.07302
# 17      STX   2024-07-30 2025-01-30               184        1.78514
# 18     RUNE   2024-07-30 2025-01-13               167        4.56914
# 13      IMX   2024-07-30 2025-01-13               167        1.41978
# 19      MKR   2024-07-30 2024-12-18               141     2778.08162
#
#     preco_saida  retorno_acumulado(%)
# 30      0.64800                -75.58
# 27    300.99464                -51.71
# 26    105.35465                -51.54
# 9    2443.92902                 -3.01
# 7    4202.42051                  3.44
# 16      0.91975                -25.90
# 25      0.27679                -51.40
# 28      2.71412                -55.45
# 3       0.89197                 19.30
# 21     15.23439                -42.03
# 24      0.75431                -47.25
# 8       0.29378                  0.71
# 12      0.44115                -16.11
# 15    133.71000                -25.32
# 10      3.24393                 -7.49
# 2       0.82209                 21.44
# 20      1.31969                -40.65
# 1     430.72495                 27.89
# 5       4.65005                  3.93
# 6       0.67457                  3.60
# 11      3.22749                -12.45
# 22      0.87706                -43.94
# 29      0.33974                -68.60
# 4      14.98695                 14.07
# 14      6.02907                -18.41
# 23   1793.96985                -45.26
# 0     167.50496                 29.78
# 17      1.31766                -26.19
# 18      3.22988                -29.31
# 13      1.18067                -16.84
# 19   1671.49480                -39.83

# %% [markdown]
# ## Exponential Coins

# %%
exc.posicoes_abertas().sort_values(by=['retorno_acumulado(%)', 'dias_em_carteira'], ascending=False)
# Out:
#   ativo ultima_entrada  dias_em_carteira  preco_entrada  preco_atual  \
# 0   BTC     2017-10-02              3055       4319.069    66937.581
# 1  HYPE     2025-01-22               386         24.322       29.328
# 2  PAXG     2026-02-04                 8       5028.853     5076.524
#
#    retorno_acumulado(%)
# 0              1449.815
# 1                20.582
# 2                 0.948

# %%
hb.posicoes_abertas().sort_values(by=['retorno_acumulado(%)'], ascending=False)
# Out:
#      ativo ultima_entrada  dias_em_carteira  preco_entrada  preco_atual  \
# 0      SOL     2023-10-23               843         31.737       79.269
# 1    SYRUP     2025-05-03               285          0.176        0.267
# 2      ETH     2025-11-03               101       3600.716     1939.432
# 3   MORPHO     2025-09-19               146          2.086        1.079
# 4      ZEC     2025-11-18                86        623.308      240.057
# 5     AERO     2025-06-17               240          0.733        0.279
# 6  VIRTUAL     2024-12-07               432          1.671        0.538
#
#    retorno_acumulado(%)
# 0               149.768
# 1                51.705
# 2               -46.138
# 3               -48.274
# 4               -61.487
# 5               -61.937
# 6               -67.804

# %%
lc.posicoes_abertas().sort_values(by=['retorno_acumulado(%)'], ascending=False)
# Out:
#    ativo ultima_entrada  dias_em_carteira  preco_entrada  preco_atual  \
# 0   META     2025-11-13                91          5.998        3.737
# 1  UMBRA     2026-01-24                19          1.658        0.687
# 2   BERT     2025-11-14                90          0.028        0.010
# 3  AVICI     2025-11-26                78          7.145        1.233
# 4  VISTA     2024-09-06               524         23.354        2.006
# 5   ANON     2025-01-07               401          9.653        0.728
# 6   MAMO     2025-07-22               205          0.151        0.011
# 7    YNE     2025-01-25               383          0.057        0.001
#
#    retorno_acumulado(%)
# 0               -37.696
# 1               -58.565
# 2               -64.286
# 3               -82.743
# 4               -91.410
# 5               -92.458
# 6               -92.715
# 7               -98.246

# %%
ac.posicoes_abertas().sort_values(by=['retorno_acumulado(%)'], ascending=False)
# Out:
#    ativo ultima_entrada  dias_em_carteira  preco_entrada  preco_atual  \
# 0    BTC     2024-07-30               562      66219.051    66937.581
# 1   PAXG     2026-02-04                 8       5028.853     5076.524
# 2   HYPE     2025-06-07               250         34.949       29.328
# 3  VISTA     2024-10-10               490          5.327        2.006
# 4    YNE     2025-01-30               378          0.047        0.001
#
#    retorno_acumulado(%)
# 0                 1.085
# 1                 0.948
# 2               -16.083
# 3               -62.343
# 4               -97.872

# %%
# calculo de beta (High Beta)

inicio = '2022-10-1'
fim = '2024-10-20'
betas=hb.rolling_beta(inicio=inicio,
                      fim=fim,
                      janela=7)

if 'USDT' in betas.columns:
  betas = betas.drop(columns='USDT')

betas
# Out:
#                ETH     MKR     SNX    AAVE     UNI  ETHDYDX    ATOM    SCRT  \
# 2022-10-08  0.9727  0.8244  0.9122  1.1794  0.7409   0.8809  1.0810  0.7910
# 2022-10-09  0.9601  0.7636  0.8881  1.2051  0.7333   0.8485  1.0270  0.7832
# 2022-10-10  0.9487  1.1674  0.9641  1.1887  0.7969   0.6112  1.0806  0.7302
# 2022-10-11  0.8499  1.0595  0.7586  1.1547  0.3210   0.2159  0.6101  0.6930
# 2022-10-12  1.0242  1.0700  1.0166  0.9442  0.6378   0.7159  0.4908  0.3433
# ...            ...     ...     ...     ...     ...      ...     ...     ...
# 2024-10-16  1.0205  0.9422  1.0101  0.8827  0.0196   0.5833  0.9365  0.3422
# 2024-10-17  0.9738  1.2215  1.0920  0.9337  0.3307   0.8550  1.1122  0.3912
# 2024-10-18  1.0911  1.5583  1.5338  1.0404  1.3624   1.0750  1.0840  0.4055
# 2024-10-19  1.1794  1.3357  1.4348  1.1806  1.7598   0.9446  0.8182 -0.0324
# 2024-10-20  1.1432  1.3006  1.2954  1.1341  1.6451   0.5973  0.7575 -0.1223
#
#               SAND     HNT  ...    DEEP     RAY  SYRUP     EUL    WELL  \
# 2022-10-08  0.7027  1.5655  ...  0.0000  0.8584    0.0 -0.1603  0.5589
# 2022-10-09  0.6996  1.5183  ...  0.0000  0.8297    0.0 -0.2194  0.6753
# 2022-10-10  0.7348  1.3389  ...  0.0000  0.9152    0.0 -0.1951  0.6473
# 2022-10-11  0.7340  1.4142  ...  0.0000  0.7490    0.0 -0.0792  0.7137
# 2022-10-12  0.6872  0.5681  ...  0.0000 -0.0883    0.0  0.4068  1.6932
# ...            ...     ...  ...     ...     ...    ...     ...     ...
# 2024-10-16  1.0395  0.4467  ... -0.1507  1.9280    0.0  2.5874  1.2632
# 2024-10-17  1.3355  0.8873  ... -0.2410  1.4476    0.0  2.9465  1.5275
# 2024-10-18  1.5730  0.7616  ...  1.5656  1.5021    0.0  2.0134  2.0147
# 2024-10-19  1.5299 -0.1108  ...  3.1185  1.4675    0.0  1.9217  3.2282
# 2024-10-20  1.5070 -0.1711  ...  4.6922  1.3658    0.0  1.9184  3.3041
#
#               AIOZ    ZBCN    LQTY     ZEC  High Beta
# 2022-10-08  0.3417  0.0000  1.0502  0.8409     0.9150
# 2022-10-09  0.3577  0.0000  1.0225  0.8452     0.8919
# 2022-10-10  0.3909  0.0000  1.1111  0.9060     0.9441
# 2022-10-11  0.3593  0.0000  1.1556  0.6569     0.7859
# 2022-10-12  0.9702  0.0000  1.3039  0.9820     0.8122
# ...            ...     ...     ...     ...        ...
# 2024-10-16  1.5678  2.2341  1.1308 -0.2527     1.1856
# 2024-10-17  1.7747  2.5355  1.6112 -0.3460     1.2896
# 2024-10-18  1.8711  2.8822  1.6433  0.7210     1.4563
# 2024-10-19  1.9011  2.5770  1.2154  0.0737     1.3460
# 2024-10-20  1.9130  2.6006  1.1454  0.1177     1.3071
#
# [744 rows x 50 columns]

# %%
#hb.df_retornos_acumulados[['SNX', 'MKR']].plot(figsize=(24, 8))

# %%
import matplotlib.pyplot as plt
from matplotlib.ticker import MaxNLocator
import matplotlib.dates as mdates

historical_mean = betas['High Beta'].rolling(window=4).mean().dropna()

# Calculate cumulative returns for High Beta and BTC
high_beta_returns = hb.calcular_retornos_acumulados(inicio=inicio, fim=fim, ponderar=True)['High Beta']
btc_returns = exc.calcular_retornos_acumulados(inicio=inicio, fim=fim, ponderar=True)['BTC']

# Calculate the daily difference between High Beta returns and BTC returns
returns_difference = high_beta_returns - btc_returns

# Assuming betas DataFrame and historical_mean have been calculated earlier

plt.figure(figsize=(24, 8))

# Plot all betas with lower alpha for shading effect
plt.plot(betas.index, betas, color='grey', alpha=0.05)

# Plot the 'High Beta' line with higher visibility
#plt.plot(betas.index, betas['High Beta'], label='Beta Semanal', color='#3F3F3F')

# Plot the rolling mean of 'High Beta'
plt.plot(historical_mean.index, historical_mean, color='red', linestyle='--', label='Média Móvel Mensal')

# Add a horizontal line at y=1
plt.axhline(y=1, color='black', linestyle='--', linewidth=1)

# Get current axis
ax = plt.gca()

# Increase y-axis granularity
ax.yaxis.set_major_locator(MaxNLocator(nbins=12))

# Limit y-axis range for Beta
ax.set_ylim(-3, 3)

# Increase x-axis granularity and format x-axis labels
ax.xaxis.set_major_locator(mdates.MonthLocator())
ax.xaxis.set_major_formatter(mdates.DateFormatter('%b-%Y'))

# Slant x-axis labels
plt.xticks(rotation=45)

# Secondary y-axis for returns
ax2 = ax.twinx()

# Plot the returns difference on the secondary y-axis
ax2.plot(returns_difference.index, returns_difference, color='#660924', label='Return Difference (High Beta - BTC)')

# Label the secondary y-axis and format as percentage
ax2.set_ylabel('Return Difference (%)', color='#660924')
ax2.tick_params(axis='y', labelcolor='#660924')
ax2.yaxis.set_major_formatter(plt.FuncFormatter(lambda x, _: f'{x * 100:.0f}%'))

# Add legends for both y-axes
ax.legend(loc='upper left')
ax2.legend(loc='upper right')

# Primary y-axis label
ax.set_ylabel('Beta', color='#3F3F3F')
ax.tick_params(axis='y', labelcolor='#3F3F3F')

plt.xlabel('Data')
plt.title('Beta semanal da carteira High Beta com Diferença de Retorno Diário (High Beta - BTC)')
plt.show()

# %%
# Resultado das carteiras

inicio = '2026-01-31' #2024-12-31 #2017-10-02 #2024-07-30
fim = '2026-02-11'
#fim = (datetime.now() - timedelta(days=1)).date()

plot_carteiras(inicio, fim, ac, exc, hb, lc, brl= False)

#plot_alocacoes(inicio,fim,ac, segmentar=True)
#plot_alocacoes(inicio,fim,exc_simu, segmentar=False)

#plot_decomposicao(inicio, fim, ac, segmentar=True, acumular=True)
#plot_decomposicao(inicio, fim, hb, segmentar=True, acumular=True)
plot_carteira_vs_ativos(inicio, fim, hb)
#plot_ativos(inicio,fim,ac)
#plot_ativos(inicio,fim,hb)
#plot_ativos(inicio,fim,lc)
#plot_dias_pos_neg(inicio, fim, exc, segmentar=True)
#plot_alocacoes(inicio,fim,exc, segmentar=True)

plot_ativos(inicio,fim,lc)
#plot_ativos(inicio,fim,hb_simu)

# %% [markdown]
# ## High beta

# %%
#inicio = '2023-11-30'
#fim = '2023-12-18'



plot_decomposicao(inicio, fim, exc, segmentar=True, acumular=True)
plot_carteira_vs_ativos(inicio, fim, exc)
plot_ativos(inicio,fim,ac)
plot_dias_pos_neg(inicio, fim, exc, segmentar=True)

# %% [markdown]
# ## Low Caps

# %%
plot_decomposicao(inicio, fim, ac, segmentar=False, acumular=True)
plot_carteira_vs_ativos(inicio, fim, ac)
plot_ativos(inicio,fim,exc)
plot_dias_pos_neg(inicio, fim, ac, segmentar=False)

# %%
#plot_correlation_matrix(exc, janela_amostral=30, filtrar_atuais=False, setorizar=False)
#plot_alocacoes(inicio=inicio,fim=fim, carteira=exc, segmentar=True)

# %%
# gráfico para saber quanto um token (ou uma cesta de tokens) retornou desde a entrada na carteira

# Medidas estatísticas de risco: VaR, hitting ratio, Sharpes, Sortinos, Calmars, StDev, etc

# Selling effectiviness


# Estudo de rebalanceamento somente durante alertas
# Estudo de rebalanceamento mensal
# planilha de posições


# Rebalanceamentos até os alertas

#exc.df_precos.to_csv("precos_exc.csv")

# %% [markdown]
# ### O pico das indicações foi aonde?

# %%
plot_correlation_matrix(exc, janela_amostral=7, filtrar_atuais=False, setorizar=True)

# %%
plot_alocacoes('2017-10-02','2024-12-30',exc,segmentar=True)

#plot_alocacoes(inicio,fim,hb,segmentar=True)
#plot_alocacoes(inicio,fim,lc,segmentar=False)

# %%
plot_comp_rebalanceamento('2025-04-30', '2025-05-31',ac) # x valorização acum. do USD, = ~18% (BRL)

# %%
plot_carteiras('2025-04-30', '2025-05-31',exc)

# %%
plot_comp_rebalanceamento('2025-04-30', '2025-05-31',lc)
# x valorização acum. do USD, = ~53% (BRL)

# %%
exc.df_aloc[-1]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\melogd1\Downloads\colabMissionControl\venv\Lib\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:578, in pandas._libs.index.StringObjectEngine._check_type()
#
# KeyError: -1
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 exc.df_aloc[-1]
#
# File c:\Users\melogd1\Downloads\colabMissionControl\venv\Lib\site-packages\pandas\core\frame.py:4378, in DataFrame.__getitem__(self, key)
#    4376 if self.columns.nlevels > 1:
#    4377     return self._getitem_multilevel(key)
# -> 4378 indexer = self.columns.get_loc(key)
#    4379 if is_integer(indexer):
#    4380     indexer = [indexer]
#
# File c:\Users\melogd1\Downloads\colabMissionControl\venv\Lib\site-packages\pandas\core\indexes\base.py:3648, in Index.get_loc(self, key)
#    3643     if isinstance(casted_key, slice) or (
#    3644         isinstance(casted_key, abc.Iterable)
#    3645         and any(isinstance(x, slice) for x in casted_key)
#    3646     ):
#    3647         raise InvalidIndexError(key) from err
# -> 3648     raise KeyError(key) from err
#    3649 except TypeError:
#    3650     # If we have a listlike key, _check_indexing_error will raise
#    3651     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3652     #  the TypeError.
#    3653     self._check_indexing_error(key)
#
# KeyError: -1
